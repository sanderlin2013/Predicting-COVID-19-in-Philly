# %%
import pandas as pd 
from datetime import datetime, timedelta

# %%
df = pd.read_csv('COVID-19_Aggregate_Cases_Current_Weekly_County_Health.csv')
df.head()
# Out:
#   Jurisdiction        Date  New Cases  7-day Average New Cases  \
# 0      Cameron  11/21/2021          2                      2.9
# 1     Sullivan  02/17/2021          0                      1.1
# 2      Cameron  11/16/2021          2                      2.9
# 3       Potter  11/14/2021          2                     10.4
# 4      Cameron  07/10/2021          0                      0.1
#
#    Cumulative cases                            Population (2019)  \
# 0                                         574               4447
# 1                                         299               6066
# 2                                         558               4447
# 3                                        2098              16526
# 4                                         310               4447
#
#    New Case Rate  7-Day Average New Case Rate  Cumulative Case Rate  \
# 0           45.0                         64.2               12907.6
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75412 entries, 0 to 75411
# Data columns (total 13 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Jurisdiction                                75412 non-null  object
#  1   Date                                        75412 non-null  object
#  2   New Cases                                   75412 non-null  int64
#  3   7-day Average New Cases                     74936 non-null  float64
#  4   Cumulative cases                            75412 non-null  int64
#  5   Population (2019)                           75412 non-null  int64
#  6   New Case Rate                               75412 non-null  float64
#  7   7-Day Average New Case Rate                 74936 non-null  float64
#  8   Cumulative Case Rate                        75412 non-null  float64
# ...

# %%
df_c = df[df.Jurisdiction == "Cameron"]

# %%
df_c['Date'] = pd.to_datetime(df_c['Date'])
df_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1109 entries, 0 to 74954
# Data columns (total 13 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Jurisdiction                                1109 non-null   object
#  1   Date                                        1109 non-null   datetime64[ns]
#  2   New Cases                                   1109 non-null   int64
#  3   7-day Average New Cases                     1102 non-null   float64
#  4   Cumulative cases                            1109 non-null   int64
#  5   Population (2019)                           1109 non-null   int64
#  6   New Case Rate                               1109 non-null   float64
#  7   7-Day Average New Case Rate                 1102 non-null   float64
#  8   Cumulative Case Rate                        1109 non-null   float64
# ...

# %%
df_c.plot(x = 'Date', y = "New Cases")
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_c.head()
# Out:
#    Jurisdiction       Date  New Cases  7-day Average New Cases  \
# 0       Cameron 2021-11-21          2                      2.9
# 2       Cameron 2021-11-16          2                      2.9
# 4       Cameron 2021-07-10          0                      0.1
# 7       Cameron 2021-07-11          0                      0.1
# 10      Cameron 2021-11-19          3                      3.4
#
#     Cumulative cases                            Population (2019)  \
# 0                                          574               4447
# 2                                          558               4447
# 4                                          310               4447
# 7                                          310               4447
# 10                                         572               4447
#
#     New Case Rate  7-Day Average New Case Rate  Cumulative Case Rate  \
# 0            45.0                         64.2               12907.6
# ...

# %%
df_c.set_index('Date', inplace=True)

# %%
df_c_sorted = df_c.sort_index()
df_c_sorted.tail()
# Out:
#            Jurisdiction  New Cases  7-day Average New Cases  \
# Date
# 2023-03-10      Cameron          0                      1.3
# 2023-03-11      Cameron          0                      1.3
# 2023-03-12      Cameron          0                      1.1
# 2023-03-13      Cameron          2                      1.3
# 2023-03-14      Cameron          1                      1.0
#
#             Cumulative cases                            Population (2019)  \
# Date
# 2023-03-10                                        1039               4447
# 2023-03-11                                        1039               4447
# 2023-03-12                                        1039               4447
# 2023-03-13                                        1041               4447
# 2023-03-14                                        1042               4447
#
#             New Case Rate  7-Day Average New Case Rate  Cumulative Case Rate  \
# Date
# ...

# %%
df_c_days = df_c_sorted.asfreq('D')
df_c_days.isnull().sum()
# Out:
# Jurisdiction                                  0
# New Cases                                     0
# 7-day Average New Cases                       7
# Cumulative cases                              0
# Population (2019)                             0
# New Case Rate                                 0
# 7-Day Average New Case Rate                   7
# Cumulative Case Rate                          0
# County FIPS Code                              0
# Longitude                                     0
# Latitude                                      0
# Georeferenced Lat & Long                      0
# dtype: int64

# %%
unique_jurisdictions = df['Jurisdiction'].unique()
len(unique_jurisdictions)
# Out:
# 68

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)

# %%
df.head()
# Out:
#            Jurisdiction  New Cases  7-day Average New Cases  \
# Date
# 2021-11-21      Cameron          2                      2.9
# 2021-02-17     Sullivan          0                      1.1
# 2021-11-16      Cameron          2                      2.9
# 2021-11-14       Potter          2                     10.4
# 2021-07-10      Cameron          0                      0.1
#
#             Cumulative cases                            Population (2019)  \
# Date
# 2021-11-21                                         574               4447
# 2021-02-17                                         299               6066
# 2021-11-16                                         558               4447
# 2021-11-14                                        2098              16526
# 2021-07-10                                         310               4447
#
#             New Case Rate  7-Day Average New Case Rate  Cumulative Case Rate  \
# Date
# ...

# %%
df = df.sort_index()
df.head()
# Out:
#            Jurisdiction  New Cases  7-day Average New Cases  \
# Date
# 2020-03-01    Lancaster          0                      NaN
# 2020-03-01        Blair          0                      NaN
# 2020-03-01  Susquehanna          0                      NaN
# 2020-03-01        Berks          0                      NaN
# 2020-03-01      Clinton          0                      NaN
#
#             Cumulative cases                            Population (2019)  \
# Date
# 2020-03-01                                           0             545724
# 2020-03-01                                           0             121829
# 2020-03-01                                           0              40328
# 2020-03-01                                           0             421164
# 2020-03-01                                           0              38632
#
#             New Case Rate  7-Day Average New Case Rate  Cumulative Case Rate  \
# Date
# ...

# %%
for jurisdiction in unique_jurisdictions:
    df_curr_jurisdiction = df[df.Jurisdiction == jurisdiction]
    df_curr_jurisdiction.asfreq('D')
    if df_curr_jurisdiction.isnull().sum().sum() != 14:
        print(jurisdiction)
