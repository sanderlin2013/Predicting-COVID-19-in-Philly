# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
# imports

import pandas as pd 
import numpy as np
from datetime import datetime, timedelta
from sklearn.decomposition import PCA
from sklearn import preprocessing
import matplotlib.pyplot as plt

# %%
#bringing in our 4 dataframes

# %%
public_data = pd.read_csv("COVID-19_Aggregate_Cases_Current_Weekly_County_Health.csv")

# %%
google_data_2020 = pd.read_csv("2020_sub_region_1_daily_2020_US_Pennsylvania_daily_symptoms_dataset.csv",  dtype=str)
#google_data_2020.head()

# %%
google_data_2021 = pd.read_csv("2021_sub_region_1_daily_2021_US_Pennsylvania_daily_symptoms_dataset(1).csv", dtype=str)
#google_data_2021["sub_region_2"].nunique()

# %%
google_data_2022 = pd.read_csv("2022_sub_region_1_daily_2022_US_Pennsylvania_daily_symptoms_dataset(1).csv", dtype=str)
#google_data_2022

# %%
# combining all our google data into one dataframe
google_dataframes = [google_data_2020, google_data_2021, google_data_2022]
google_data = pd.concat(google_dataframes)
google_data.head()
# Out:
#   country_region_code country_region  sub_region_1 sub_region_1_code  \
# 0                  US  United States  Pennsylvania             US-PA
# 1                  US  United States  Pennsylvania             US-PA
# 2                  US  United States  Pennsylvania             US-PA
# 3                  US  United States  Pennsylvania             US-PA
# 4                  US  United States  Pennsylvania             US-PA
#
#   sub_region_2 sub_region_2_code                     place_id        date  \
# 0          NaN               NaN  ChIJieUyHiaALYgRPbQiUEchRsI  2020-01-01
# 1          NaN               NaN  ChIJieUyHiaALYgRPbQiUEchRsI  2020-01-02
# 2          NaN               NaN  ChIJieUyHiaALYgRPbQiUEchRsI  2020-01-03
# 3          NaN               NaN  ChIJieUyHiaALYgRPbQiUEchRsI  2020-01-04
# 4          NaN               NaN  ChIJieUyHiaALYgRPbQiUEchRsI  2020-01-05
#
#   symptom:Abdominal obesity symptom:Abdominal pain  ... symptom:Wart  \
# 0                      2.37                   4.85  ...         1.22
# 1                      2.28                   4.74  ...         1.34
# 2                      2.04                   4.62  ...         1.23
# 3                      2.25                   4.83  ...         1.22
# 4                       2.5                    4.7  ...         1.19
#
#   symptom:Water retention symptom:Weakness symptom:Weight gain symptom:Wheeze  \
# 0                    0.24             0.34                3.29           0.38
# 1                    0.24              0.4                3.39           0.38
# 2                    0.23             0.38                3.17           0.34
# 3                    0.26              0.4                3.15           0.32
# 4                    0.25             0.37                3.38           0.34
#
#   symptom:Xeroderma symptom:Xerostomia symptom:Yawn symptom:hyperhidrosis  \
# 0              2.49               0.35         0.16                  0.47
# 1               2.4                0.4         0.16                  0.53
# 2              2.19               0.38         0.16                  0.51
# 3              2.46               0.39         0.17                  0.54
# 4               2.5               0.38         0.16                  0.53
#
#   symptom:pancreatitis
# 0                 0.38
# 1                 0.45
# 2                 0.41
# 3                 0.35
# 4                 0.36
#
# [5 rows x 430 columns]

# %%
google_data.drop(columns=google_data.columns[0:4], inplace=True)
google_data.head()
# Out:
#   sub_region_2 sub_region_2_code                     place_id        date  \
# 0          NaN               NaN  ChIJieUyHiaALYgRPbQiUEchRsI  2020-01-01
# 1          NaN               NaN  ChIJieUyHiaALYgRPbQiUEchRsI  2020-01-02
# 2          NaN               NaN  ChIJieUyHiaALYgRPbQiUEchRsI  2020-01-03
# 3          NaN               NaN  ChIJieUyHiaALYgRPbQiUEchRsI  2020-01-04
# 4          NaN               NaN  ChIJieUyHiaALYgRPbQiUEchRsI  2020-01-05
#
#   symptom:Abdominal obesity symptom:Abdominal pain symptom:Acne  \
# 0                      2.37                   4.85         8.27
# 1                      2.28                   4.74         8.33
# 2                      2.04                   4.62         7.79
# 3                      2.25                   4.83         8.38
# 4                       2.5                    4.7          8.4
#
#   symptom:Actinic keratosis symptom:Acute bronchitis symptom:Adrenal crisis  \
# 0                      0.25                     0.91                    0.1
# 1                      0.31                     0.93                    0.1
# 2                      0.29                     0.95                    0.1
# 3                      0.25                     0.89                   0.09
# 4                      0.25                      0.8                   0.09
#
#    ... symptom:Wart symptom:Water retention symptom:Weakness  \
# 0  ...         1.22                    0.24             0.34
# 1  ...         1.34                    0.24              0.4
# 2  ...         1.23                    0.23             0.38
# 3  ...         1.22                    0.26              0.4
# 4  ...         1.19                    0.25             0.37
#
#   symptom:Weight gain symptom:Wheeze symptom:Xeroderma symptom:Xerostomia  \
# 0                3.29           0.38              2.49               0.35
# 1                3.39           0.38               2.4                0.4
# 2                3.17           0.34              2.19               0.38
# 3                3.15           0.32              2.46               0.39
# 4                3.38           0.34               2.5               0.38
#
#   symptom:Yawn symptom:hyperhidrosis symptom:pancreatitis
# 0         0.16                  0.47                 0.38
# 1         0.16                  0.53                 0.45
# 2         0.16                  0.51                 0.41
# 3         0.17                  0.54                 0.35
# 4         0.16                  0.53                 0.36
#
# [5 rows x 426 columns]

# %%
google_data['date']= pd.to_datetime(google_data['date'])
#google_data['date']

# %%
# make the date our index, then sort by the date index
google_data.set_index('date', inplace=True)
sorted_google_data = google_data.sort_index()

# %%
sorted_google_data
# Out:
#                  sub_region_2 sub_region_2_code                     place_id  \
# date
# 2020-01-01                NaN               NaN  ChIJieUyHiaALYgRPbQiUEchRsI
# 2020-01-01       Wayne County             42127  ChIJi2kzXE6xxIkR6haLl-5Z1KY
# 2020-01-01      McKean County             42083  ChIJXWzIq8TBzYkRpK8OyuDlIi8
# 2020-01-01      Carbon County             42025  ChIJUclpSMyxxYkReO80rzNlIyE
# 2020-01-01      Potter County             42105  ChIJYUDex5jnzYkRV-hIg0hwTPA
# ...                       ...               ...                          ...
# 2022-11-13      Monroe County             42089  ChIJo1Dq5_-NxIkRf4gUnFVPgUI
# 2022-11-13  Montgomery County             42091  ChIJ6yayVjmcxokRvV1Q-SKqC0s
# 2022-11-13     Montour County             42093  ChIJgTHtyUJwz4kRXELxvBdMJSc
# 2022-11-13       Blair County             42013  ChIJNVhk9IGQy4kRLiloHZ-z5yo
# 2022-11-13        York County             42133  ChIJ0d0uysfzyIkRfznnnLSl6k8
#
#            symptom:Abdominal obesity symptom:Abdominal pain symptom:Acne  \
# date
# 2020-01-01                      2.37                   4.85         8.27
# 2020-01-01                       NaN                   5.07         6.33
# 2020-01-01                       NaN                   4.31         8.11
# 2020-01-01                      2.75                   3.91          7.5
# 2020-01-01                       NaN                    NaN          NaN
# ...                              ...                    ...          ...
# 2022-11-13                       1.3                   5.49         6.93
# 2022-11-13                      1.36                   3.92          6.1
# 2022-11-13                       NaN                    NaN          NaN
# 2022-11-13                      1.03                   5.88         6.44
# 2022-11-13                      1.42                   4.86         6.39
#
#            symptom:Actinic keratosis symptom:Acute bronchitis  \
# date
# 2020-01-01                      0.25                     0.91
# 2020-01-01                       NaN                      NaN
# 2020-01-01                       NaN                      NaN
# 2020-01-01                       NaN                      NaN
# 2020-01-01                       NaN                      NaN
# ...                              ...                      ...
# 2022-11-13                       NaN                      NaN
# 2022-11-13                      0.24                     0.69
# 2022-11-13                       NaN                      NaN
# 2022-11-13                       NaN                      NaN
# 2022-11-13                      0.32                     0.65
#
#            symptom:Adrenal crisis symptom:Ageusia  ... symptom:Wart  \
# date                                               ...
# 2020-01-01                    0.1            0.04  ...         1.22
# 2020-01-01                    NaN             NaN  ...          NaN
# 2020-01-01                    NaN             NaN  ...          NaN
# 2020-01-01                    NaN             NaN  ...          NaN
# 2020-01-01                    NaN             NaN  ...          NaN
# ...                           ...             ...  ...          ...
# 2022-11-13                    NaN             NaN  ...         1.35
# 2022-11-13                   0.12            0.11  ...         0.92
# 2022-11-13                    NaN             NaN  ...          NaN
# 2022-11-13                    NaN             NaN  ...         0.86
# 2022-11-13                    NaN             NaN  ...         1.15
#
#            symptom:Water retention symptom:Weakness symptom:Weight gain  \
# date
# 2020-01-01                    0.24             0.34                3.29
# 2020-01-01                     NaN              NaN                2.53
# 2020-01-01                     NaN              NaN                 NaN
# 2020-01-01                     NaN              NaN                 3.8
# 2020-01-01                     NaN              NaN                 NaN
# ...                            ...              ...                 ...
# 2022-11-13                     NaN              NaN                 3.9
# 2022-11-13                    0.14             0.43                2.46
# 2022-11-13                     NaN              NaN                 NaN
# 2022-11-13                     NaN              NaN                3.84
# 2022-11-13                    0.52             0.31                2.74
#
#            symptom:Wheeze symptom:Xeroderma symptom:Xerostomia symptom:Yawn  \
# date
# 2020-01-01           0.38              2.49               0.35         0.16
# 2020-01-01            NaN               NaN                NaN          NaN
# 2020-01-01            NaN               NaN                NaN          NaN
# 2020-01-01            NaN               1.8                NaN          NaN
# 2020-01-01            NaN               NaN                NaN          NaN
# ...                   ...               ...                ...          ...
# 2022-11-13            NaN              2.63                NaN          NaN
# 2022-11-13           0.27              2.16               0.39         0.17
# 2022-11-13            NaN               NaN                NaN          NaN
# 2022-11-13            NaN              2.45                NaN          NaN
# 2022-11-13           0.45              2.03               0.47          NaN
#
#            symptom:hyperhidrosis symptom:pancreatitis
# date
# 2020-01-01                  0.47                 0.38
# 2020-01-01                   NaN                  NaN
# 2020-01-01                   NaN                  NaN
# 2020-01-01                   NaN                  NaN
# 2020-01-01                   NaN                  NaN
# ...                          ...                  ...
# 2022-11-13                  0.78                  NaN
# 2022-11-13                  0.41                  0.3
# 2022-11-13                   NaN                  NaN
# 2022-11-13                   NaN                  NaN
# 2022-11-13                  0.37                 0.53
#
# [68805 rows x 425 columns]

# %%
# lets check for missing dates - starting with Philly
google_philly= sorted_google_data[sorted_google_data.sub_region_2 == 'Philadelphia County']

# %%
google_philly
# Out:
#                    sub_region_2 sub_region_2_code  \
# date
# 2020-01-01  Philadelphia County             42101
# 2020-01-02  Philadelphia County             42101
# 2020-01-03  Philadelphia County             42101
# 2020-01-04  Philadelphia County             42101
# 2020-01-05  Philadelphia County             42101
# ...                         ...               ...
# 2022-11-09  Philadelphia County             42101
# 2022-11-10  Philadelphia County             42101
# 2022-11-11  Philadelphia County             42101
# 2022-11-12  Philadelphia County             42101
# 2022-11-13  Philadelphia County             42101
#
#                                place_id symptom:Abdominal obesity  \
# date
# 2020-01-01  ChIJ60u11Ni3xokRhBCHQtzJmsM                      2.35
# 2020-01-02  ChIJ60u11Ni3xokRhBCHQtzJmsM                      2.37
# 2020-01-02               0.34         0.14                   0.5
# 2020-01-03                0.3         0.18                  0.51
# 2020-01-04               0.42         0.24                  0.48
# 2020-01-05               0.35          0.2                  0.49
# ...                       ...          ...                   ...
# 2022-11-09               0.34         0.19                  0.45
# 2022-11-10               0.35         0.13                  0.39
# 2022-11-11               0.42         0.14                  0.44
# 2022-11-12               0.35         0.14                  0.47
# 2022-11-13               0.39         0.14                  0.45
#
#            symptom:pancreatitis
# date
# 2020-01-01                 0.25
# 2020-01-02                 0.34
# 2020-01-03                  0.3
# 2020-01-04                 0.27
# 2020-01-05                 0.24
# ...                         ...
# 2022-11-09                 0.31
# 2022-11-10                 0.27
# 2022-11-11                 0.28
# 2022-11-12                 0.26
# 2022-11-13                 0.26
#
# [1048 rows x 425 columns]

# %%
#https://stackoverflow.com/questions/52044348/check-for-any-missing-dates-in-the-index
#checks for any missing dates! 
outcome = pd.date_range(start = '2020-01-01', end = '2022-11-13' ).difference(google_philly.index)

# %%
outcome
# Out:
# DatetimeIndex([], dtype='datetime64[ns]', freq=None)

# %%
google_counties = sorted_google_data['sub_region_2'].unique()
google_counties
# Out:
# array([nan, 'Wayne County', 'McKean County', 'Carbon County',
#        'Potter County', 'Fulton County', 'Mifflin County', 'Adams County',
#        'Bradford County', 'Cumberland County', 'Juniata County',
#        'Perry County', 'Elk County', 'Susquehanna County',
#        'Bedford County', 'Northampton County', 'Lycoming County',
#        'Sullivan County', 'Greene County', 'Somerset County',
#        'Cambria County', 'Bucks County', 'Erie County',
#        'Northumberland County', 'Lancaster County', 'Washington County',
#        'Monroe County', 'Mercer County', 'Dauphin County',
#        'Butler County', 'Schuylkill County', 'Fayette County',
#        'Lawrence County', 'Armstrong County', 'Franklin County',
#        'Warren County', 'Lackawanna County', 'Delaware County',
#        'Montgomery County', 'Crawford County', 'Westmoreland County',
#        'Chester County', 'Lehigh County', 'Berks County',
#        'Lebanon County', 'Wyoming County', 'Jefferson County',
#        'York County', 'Clearfield County', 'Beaver County',
#        'Clarion County', 'Union County', 'Indiana County',
#        'Philadelphia County', 'Montour County', 'Luzerne County',
#        'Tioga County', 'Clinton County', 'Snyder County',
#        'Venango County', 'Centre County', 'Pike County', 'Blair County',
#        'Allegheny County', 'Huntingdon County', 'Columbia County'],
#       dtype=object)

# %%
#check for missing dates in all our google data
for county in google_counties:
    google_county = sorted_google_data[sorted_google_data.sub_region_2 == county]
    outcome = pd.date_range(start = '2020-01-01', end = '2022-11-13' ).difference(google_county.index)
    print(county, outcome)
# Out:
# nan DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10',
#                ...
#                '2022-11-04', '2022-11-05', '2022-11-06', '2022-11-07',
#                '2022-11-08', '2022-11-09', '2022-11-10', '2022-11-11',
#                '2022-11-12', '2022-11-13'],
#               dtype='datetime64[ns]', length=1048, freq=None)
# Wayne County DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# McKean County DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Carbon County DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Potter County DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Fulton County DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Mifflin County DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Adams County DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Bradford County DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Cumberland County DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Juniata County DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Perry County DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Elk County DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Susquehanna County DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Bedford County DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Northampton County DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Lycoming County DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Sullivan County DatetimeIndex(['2020-01-02', '2020-01-04', '2020-01-05', '2020-01-08',
#                '2020-01-09', '2020-01-11', '2020-01-12', '2020-01-13',
#                '2020-01-15', '2020-01-17',
#                ...
#                '2022-10-11', '2022-10-12', '2022-10-14', '2022-10-15',
#                '2022-10-24', '2022-10-27', '2022-10-29', '2022-10-30',
#                '2022-11-01', '2022-11-04'],
#               dtype='datetime64[ns]', length=363, freq=None)
# Greene County DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Somerset County DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Cambria County DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Bucks County DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Erie County DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Northumberland County DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Lancaster County DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Washington County DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Monroe County DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Mercer County DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Dauphin County DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Butler County DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Schuylkill County DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Fayette County DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Lawrence County DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Armstrong County DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Franklin County DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Warren County DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Lackawanna County DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Delaware County DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Montgomery County DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Crawford County DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Westmoreland County DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Chester County DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Lehigh County DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Berks County DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Lebanon County DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Wyoming County DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Jefferson County DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# York County DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Clearfield County DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Beaver County DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Clarion County DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Union County DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Indiana County DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Philadelphia County DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Montour County DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Luzerne County DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Tioga County DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Clinton County DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Snyder County DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Venango County DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Centre County DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Pike County DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Blair County DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Allegheny County DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Huntingdon County DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Columbia County DatetimeIndex([], dtype='datetime64[ns]', freq=None)

# %%
#google_philly= sorted_google_data[sorted_google_data.sub_region_2 == 'Philadelphia County']
 
# sullivan_ct = sorted_google_data[sorted_google_data.sub_region_2 == 'Sullivan County']
# s_outcome = pd.date_range(start = '2020-01-01', end = '2022-11-13' ).difference(sullivan_ct.index)
# s_outcome.difference

# %%
#sorted_google_data["sub_region_2"] = sorted_google_data["sub_region_2"].astype("string")

# %%
#dropping NaN data
sorted_google_data= sorted_google_data[sorted_google_data["sub_region_2"].notna()]
#drop Sullivan County - too many missing dates
sorted_google_data= sorted_google_data[sorted_google_data["sub_region_2"] != 'Sullivan County']

# %%
sorted_google_data["sub_region_2"].nunique()
# Out:
# 64

# %%
sorted_google_data = sorted_google_data.applymap(lambda x: str(x).rstrip('County').rstrip())

# %%
sorted_google_data
# Out:
#            sub_region_2 sub_region_2_code                     place_id  \
# date
# 2020-01-01        Wayne             42127  ChIJi2kzXE6xxIkR6haLl-5Z1KY
# 2020-01-01       McKean             42083  ChIJXWzIq8TBzYkRpK8OyuDlIi8
# 2020-01-01       Carbon             42025  ChIJUclpSMyxxYkReO80rzNlIyE
# 2020-01-01       Potter             42105  ChIJYUDex5jnzYkRV-hIg0hwTPA
# 2020-01-01       Fulton             42057  ChIJF88rDvozyokRqgjs0ttEA30
# ...                 ...               ...                          ...
# 2022-11-13       Monroe             42089  ChIJo1Dq5_-NxIkRf4gUnFVPgUI
# 2022-11-13   Montgomery             42091  ChIJ6yayVjmcxokRvV1Q-SKqC0s
# 2022-11-13      Montour             42093  ChIJgTHtyUJwz4kRXELxvBdMJSc
# 2022-11-13        Blair             42013    ChIJNVhk9IGQy4kRLiloHZ-z5
# 2022-11-13         York             42133  ChIJ0d0uysfzyIkRfznnnLSl6k8
#
#            symptom:Abdominal obesity symptom:Abdominal pain symptom:Acne  \
# date
# 2020-01-01                        na                   5.07         6.33
# 2020-01-01                        na                   4.31         8.11
# 2020-01-01                      2.75                   3.91          7.5
# 2020-01-01                        na                     na           na
# 2020-01-01                        na                     na           na
# ...                              ...                    ...          ...
# 2022-11-13                       1.3                   5.49         6.93
# 2022-11-13                      1.36                   3.92          6.1
# 2022-11-13                        na                     na           na
# 2022-11-13                      1.03                   5.88         6.44
# 2022-11-13                      1.42                   4.86         6.39
#
#            symptom:Actinic keratosis symptom:Acute bronchitis  \
# date
# 2020-01-01                        na                       na
# 2020-01-01                        na                       na
# 2020-01-01                        na                       na
# 2020-01-01                        na                       na
# 2020-01-01                        na                       na
# ...                              ...                      ...
# 2022-11-13                        na                       na
# 2022-11-13                      0.24                     0.69
# 2022-11-13                        na                       na
# 2022-11-13                        na                       na
# 2022-11-13                      0.32                     0.65
#
#            symptom:Adrenal crisis symptom:Ageusia  ... symptom:Wart  \
# date                                               ...
# 2020-01-01                     na              na  ...           na
# 2020-01-01                     na              na  ...           na
# 2020-01-01                     na              na  ...           na
# 2020-01-01                     na              na  ...           na
# 2020-01-01                     na              na  ...           na
# ...                           ...             ...  ...          ...
# 2022-11-13                     na              na  ...         1.35
# 2022-11-13                   0.12            0.11  ...         0.92
# 2022-11-13                     na              na  ...           na
# 2022-11-13                     na              na  ...         0.86
# 2022-11-13                     na              na  ...         1.15
#
#            symptom:Water retention symptom:Weakness symptom:Weight gain  \
# date
# 2020-01-01                      na               na                2.53
# 2020-01-01                      na               na                  na
# 2020-01-01                      na               na                 3.8
# 2020-01-01                      na               na                  na
# 2020-01-01                      na               na                  na
# ...                            ...              ...                 ...
# 2022-11-13                      na               na                 3.9
# 2022-11-13                    0.14             0.43                2.46
# 2022-11-13                      na               na                  na
# 2022-11-13                      na               na                3.84
# 2022-11-13                    0.52             0.31                2.74
#
#            symptom:Wheeze symptom:Xeroderma symptom:Xerostomia symptom:Yawn  \
# date
# 2020-01-01             na                na                 na           na
# 2020-01-01             na                na                 na           na
# 2020-01-01             na               1.8                 na           na
# 2020-01-01             na                na                 na           na
# 2020-01-01             na                na                 na           na
# ...                   ...               ...                ...          ...
# 2022-11-13             na              2.63                 na           na
# 2022-11-13           0.27              2.16               0.39         0.17
# 2022-11-13             na                na                 na           na
# 2022-11-13             na              2.45                 na           na
# 2022-11-13           0.45              2.03               0.47           na
#
#            symptom:hyperhidrosis symptom:pancreatitis
# date
# 2020-01-01                    na                   na
# 2020-01-01                    na                   na
# 2020-01-01                    na                   na
# 2020-01-01                    na                   na
# 2020-01-01                    na                   na
# ...                          ...                  ...
# 2022-11-13                  0.78                   na
# 2022-11-13                  0.41                  0.3
# 2022-11-13                    na                   na
# 2022-11-13                    na                   na
# 2022-11-13                  0.37                 0.53
#
# [67072 rows x 425 columns]

# %%
dated_google = sorted_google_data #.loc["2021-01-01" :]
dated_google["symptom:Abdominal obesity"].max(skipna = True)
# Out:
# 'na'

# %%
dated_google = dated_google.replace('na', np.NaN)

# %%
google_counties_fin = list(sorted_google_data['sub_region_2'].unique())
google_counties_fin.sort()
#google_counties_fin

# %%
public_data.head()
# Out:
#   Jurisdiction        Date  New Cases  7-day Average New Cases  \
# 0      Cameron  11/21/2021          2                      2.9
# 1     Sullivan  02/17/2021          0                      1.1
# 2      Cameron  11/16/2021          2                      2.9
# 3       Potter  11/14/2021          2                     10.4
# 4      Cameron  07/10/2021          0                      0.1
#
#    Cumulative cases                            Population (2019)  \
# 0                                         574               4447
# 1                                         299               6066
# 2                                         558               4447
# 3                                        2098              16526
# 4                                         310               4447
#
#    New Case Rate  7-Day Average New Case Rate  Cumulative Case Rate  \
# 0           45.0                         64.2               12907.6
# 1            0.0                         18.8                4929.1
# 2           45.0                         64.2               12547.8
# 3           12.1                         63.1               12695.1
# 4            0.0                          3.2                6971.0
#
#    County FIPS Code  Longitude   Latitude          Georeferenced Lat & Long
# 0             42023 -78.209169  41.438803  POINT (-78.20916932 41.43880265)
# 1             42113 -76.514792  41.448099    POINT (-76.5147922 41.4480994)
# 2             42023 -78.209169  41.438803  POINT (-78.20916932 41.43880265)
# 3             42105 -77.898792  41.744206  POINT (-77.89879229 41.74420644)
# 4             42023 -78.209169  41.438803  POINT (-78.20916932 41.43880265)

# %%
public_data['Date'] = pd.to_datetime(public_data['Date'])
public_data.set_index('Date', inplace=True)
sorted_public_data = public_data.sort_index()

# %%
#sorted_public_data

# %%
unique_jurisdictions= list(sorted_public_data['Jurisdiction'].unique())
unique_jurisdictions.sort()
#unique_jurisdictions

# %%
for jurisdiction in unique_jurisdictions:
    public_jurisdiction = sorted_public_data[sorted_public_data.Jurisdiction == jurisdiction]
    outcome = pd.date_range(start = '2020-03-01', end = '2023-03-14' ).difference(public_jurisdiction.index)
    print(jurisdiction, outcome)
# Out:
# Adams DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Allegheny DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Armstrong DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Beaver DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Bedford DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Berks DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Blair DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Bradford DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Bucks DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Butler DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Cambria DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Cameron DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Carbon DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Centre DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Chester DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Clarion DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Clearfield DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Clinton DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Columbia DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Crawford DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Cumberland DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Dauphin DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Delaware DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Elk DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Erie DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Fayette DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Forest DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Franklin DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Fulton DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Greene DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Huntingdon DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Indiana DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Jefferson DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Juniata DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Lackawanna DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Lancaster DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Lawrence DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Lebanon DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Lehigh DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Luzerne DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Lycoming DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# McKean DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Mercer DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Mifflin DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Monroe DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Montgomery DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Montour DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Northampton DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Northumberland DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Pennsylvania DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Perry DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Philadelphia DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Pike DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Potter DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Schuylkill DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Snyder DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Somerset DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Sullivan DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Susquehanna DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Tioga DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Union DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Venango DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Warren DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Washington DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Wayne DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Westmoreland DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# Wyoming DatetimeIndex([], dtype='datetime64[ns]', freq=None)
# York DatetimeIndex([], dtype='datetime64[ns]', freq=None)

# %%
# see the differences between our two datasets
not_in_google = list(set(unique_jurisdictions) - set(google_counties_fin))

# %%
not_in_google
# Out:
# ['Sullivan', 'Pennsylvania', 'Cameron', 'Forest']

# %%
# save 'Pennsylvania' set separately
public_PA = sorted_public_data[sorted_public_data.Jurisdiction== 'Pennsylvania']
#public_PA.iloc[: -7745]

# %%
public_PA.loc[: "2022-11-13"]
# Out:
#             Jurisdiction  New Cases  7-day Average New Cases  \
# Date
# 2020-03-01  Pennsylvania          0                      NaN
# 2020-03-02  Pennsylvania          0                      NaN
# 2020-03-03  Pennsylvania          0                      NaN
# 2020-03-04  Pennsylvania          0                      NaN
# 2020-03-05  Pennsylvania          0                      NaN
# ...                  ...        ...                      ...
# 2022-11-09  Pennsylvania       1745                   1717.6
# 2022-11-10  Pennsylvania       1961                   1664.1
# 2020-03-01                                           0             121829
# 2020-03-01                                           0              40328
# 2020-03-01                                           0             421164
# 2020-03-01                                           0              38632
# ...                                                ...                ...
# 2022-11-13                                       13273              50668
# 2022-11-13                                       42118             162385
# 2022-11-13                                       10202              36233
# 2022-11-13                                       18432              64964
# 2022-11-13                                        9764              40591
#
#             New Case Rate  7-Day Average New Case Rate  Cumulative Case Rate  \
# Date
# 2020-03-01            0.0                          NaN                   0.0
# 2020-03-01            0.0                          NaN                   0.0
# 2020-03-01            0.0                          NaN                   0.0
# 2020-03-01            0.0                          NaN                   0.0
# 2020-03-01            0.0                          NaN                   0.0
# ...                   ...                          ...                   ...
# 2022-11-13            3.9                          8.7               26196.0
# 2022-11-13            3.7                         11.1               25937.1
# 2022-11-13            2.8                         11.4               28156.7
# 2022-11-13            9.2                         13.4               28372.6
# 2022-11-13            2.5                         19.4               24054.6
#
#             County FIPS Code  Longitude   Latitude  \
# Date
# 2020-03-01             42071 -76.251388  40.045908
# 2020-03-01             42013 -78.349077  40.485550
# 2020-03-01             42115 -75.802503  41.820569
# 2020-03-01             42011 -75.930773  40.419396
# 2020-03-01             42035 -77.642838  41.232863
# ...                      ...        ...        ...
# 2022-11-13             42121 -79.762866  41.403413
# 2022-11-13             42027 -77.825001  40.919314
# 2022-11-13             42059 -80.229438  39.854804
# 2022-11-13             42037 -76.410022  41.049121
# 2022-11-13             42117 -77.257881  41.773338
#
#                     Georeferenced Lat & Long
# Date
# 2020-03-01  POINT (-76.25138768 40.04590796)
# 2020-03-01  POINT (-78.34907687 40.48555024)
# 2020-03-01   POINT (-75.80250303 41.8205686)
# 2020-03-01  POINT (-75.93077327 40.41939635)
# 2020-03-01   POINT (-77.6428376 41.23286274)
# ...                                      ...
# 2022-11-13  POINT (-79.76286561 41.40341259)
# 2022-11-13   POINT (-77.82500112 40.9193135)
# 2022-11-13  POINT (-80.22943817 39.85480393)
# 2022-11-13   POINT (-76.4100218 41.04912086)
# 2022-11-13  POINT (-77.25788076 41.77333834)
#
# [63232 rows x 12 columns]

# %%
# lets get rid of columns in the google data with lots of missing values
col_thresh_limit= len(dated_google) * 0.35

dated_google = dated_google.dropna(thresh=col_thresh_limit,axis=1)

# %%
dated_google
# Out:
#            sub_region_2 sub_region_2_code                     place_id  \
# date
# 2020-01-01        Wayne             42127  ChIJi2kzXE6xxIkR6haLl-5Z1KY
# 2020-01-01       McKean             42083  ChIJXWzIq8TBzYkRpK8OyuDlIi8
# 2020-01-01       Carbon             42025  ChIJUclpSMyxxYkReO80rzNlIyE
# 2020-01-01       Potter             42105  ChIJYUDex5jnzYkRV-hIg0hwTPA
# 2020-01-01       Fulton             42057  ChIJF88rDvozyokRqgjs0ttEA30
# ...                 ...               ...                          ...
# 2022-11-13       Monroe             42089  ChIJo1Dq5_-NxIkRf4gUnFVPgUI
# 2022-11-13   Montgomery             42091  ChIJ6yayVjmcxokRvV1Q-SKqC0s
# 2022-11-13      Montour             42093  ChIJgTHtyUJwz4kRXELxvBdMJSc
# 2022-11-13        Blair             42013    ChIJNVhk9IGQy4kRLiloHZ-z5
# 2022-11-13            0.95             2.61         0.92                2.46
# 2022-11-13             NaN              NaN          NaN                 NaN
# 2022-11-13             0.9             3.68         0.86                3.84
# 2022-11-13            1.18             2.71         1.15                2.74
#
#            symptom:Xeroderma
# date
# 2020-01-01               NaN
# 2020-01-01               NaN
# 2020-01-01               1.8
# 2020-01-01               NaN
# 2020-01-01               NaN
# ...                      ...
# 2022-11-13              2.63
# 2022-11-13              2.16
# 2022-11-13               NaN
# 2022-11-13              2.45
# 2022-11-13              2.03
#
# [67072 rows x 132 columns]

# %%
google_col = dated_google.columns.to_list()
google_col[3:]
# Out:
# ['symptom:Abdominal obesity',
#  'symptom:Abdominal pain',
#  'symptom:Acne',
#  'symptom:Alcoholism',
#  'symptom:Allergy',
#  'symptom:Anemia',
#  'symptom:Angina pectoris',
#  'symptom:Anxiety',
#  'symptom:Arthritis',
#  'symptom:Asperger syndrome',
#  'symptom:Asthma',
#  'symptom:Attention deficit hyperactivity disorder',
#  'symptom:Autoimmune disease',
#  'symptom:Back pain',
#  'symptom:Bacterial vaginosis',
#  'symptom:Bleeding',
#  'symptom:Bloating',
#  'symptom:Boil',
#  'symptom:Bone fracture',
#  'symptom:Bruise',
#  'symptom:Burn',
#  'symptom:Candidiasis',
#  'symptom:Canker sore',
#  'symptom:Carpal tunnel syndrome',
#  'symptom:Chest pain',
#  'symptom:Chronic pain',
#  'symptom:Common cold',
#  'symptom:Conjunctivitis',
#  'symptom:Constipation',
#  'symptom:Cough',
#  'symptom:Cramp',
#  'symptom:Dandruff',
#  'symptom:Dementia',
#  'symptom:Depression',
#  'symptom:Dermatitis',
#  'symptom:Diabetes',
#  'symptom:Diarrhea',
#  'symptom:Dizziness',
#  'symptom:Dysmenorrhea',
#  'symptom:Ear pain',
#  'symptom:Edema',
#  'symptom:Epilepsy',
#  'symptom:Erectile dysfunction',
#  'symptom:Fatigue',
#  'symptom:Fever',
#  'symptom:Flatulence',
#  'symptom:Gastroesophageal reflux disease',
#  'symptom:Generalized anxiety disorder',
#  'symptom:Genital wart',
#  'symptom:Gout',
#  'symptom:Hair loss',
#  'symptom:Hay fever',
#  'symptom:Headache',
#  'symptom:Heart arrhythmia',
#  'symptom:Heartburn',
#  'symptom:Hemorrhoids',
#  'symptom:Hepatitis',
#  'symptom:Hip pain',
#  'symptom:Hives',
#  'symptom:Hypercholesterolemia',
#  'symptom:Hyperglycemia',
#  'symptom:Hypertension',
#  'symptom:Hyperthyroidism',
#  'symptom:Hypoglycemia',
#  'symptom:Hypotension',
#  'symptom:Hypothyroidism',
#  'symptom:Implantation bleeding',
#  'symptom:Indigestion',
#  'symptom:Infection',
#  'symptom:Inflammation',
#  'symptom:Inflammatory bowel disease',
#  'symptom:Insomnia',
#  'symptom:Iron deficiency',
#  'symptom:Itch',
#  'symptom:Kidney failure',
#  'symptom:Kidney stone',
#  'symptom:Knee Pain',
#  'symptom:Lactose intolerance',
#  'symptom:Lesion',
#  'symptom:Low back pain',
#  'symptom:Major depressive disorder',
#  'symptom:Migraine',
#  'symptom:Mood disorder',
#  'symptom:Morning sickness',
#  'symptom:Mouth ulcer',
#  'symptom:Myocardial infarction',
#  'symptom:Nasal congestion',
#  'symptom:Nausea',
#  'symptom:Neck pain',
#  'symptom:Obesity',
#  'symptom:Otitis',
#  'symptom:Otitis media',
#  'symptom:Pain',
#  'symptom:Panic attack',
#  'symptom:Paresthesia',
#  'symptom:Peripheral neuropathy',
#  'symptom:Perspiration',
#  'symptom:Pneumonia',
#  'symptom:Podalgia',
#  'symptom:Psychosis',
#  'symptom:Scar',
#  'symptom:Sciatica',
#  'symptom:Sharp pain',
#  'symptom:Shortness of breath',
#  'symptom:Sinusitis',
#  'symptom:Skin condition',
#  'symptom:Skin rash',
#  'symptom:Skin ulcer',
#  'symptom:Sleep apnea',
#  'symptom:Sleep disorder',
#  'symptom:Snoring',
#  'symptom:Sore throat',
#  'symptom:Stroke',
#  'symptom:Swelling',
#  'symptom:Swollen lymph nodes',
#  'symptom:Tachycardia',
#  'symptom:Tinnitus',
#  'symptom:Toothache',
#  'symptom:Tumor',
#  'symptom:Type 2 diabetes',
#  'symptom:Urinary incontinence',
#  'symptom:Urinary tract infection',
#  'symptom:Uterine contraction',
#  'symptom:Vaginal discharge',
#  'symptom:Vertigo',
#  'symptom:Vomiting',
#  'symptom:Wart',
#  'symptom:Weight gain',
#  'symptom:Xeroderma']

# %%
#changing our symptoms columns dtype to 
dated_google[google_col[3:]] = dated_google[google_col[3:]].astype(float)

# %%
dated_google.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 67072 entries, 2020-01-01 to 2022-11-13
# Columns: 132 entries, sub_region_2 to symptom:Xeroderma
# dtypes: float64(129), object(3)
# memory usage: 68.1+ MB

# %%
dated_google.isnull().sum().sum()
# Out:
# 3354424

# %%
#getting a list of all counties where 10% or more of their data is missing
county_max_nan = []

for county in google_counties_fin:
    county_df = dated_google[dated_google.sub_region_2 == county]
    # can see how many NaN's are in each county
    missing_data_per_county = county_df.isnull().sum().sum()
    # finding the limit (10%)
    county_thresh_limit = len(county_df) * 132 * .10
    if missing_data_per_county >= county_thresh_limit:
        county_max_nan.append(county)
    
len(county_max_nan)
# Out:
# 39

# %%
#remove counties from the google dataset with 10% or more missing data
for item in county_max_nan:
    dated_google = dated_google[dated_google["sub_region_2"] != item ]

dated_google.head()
# Out:
#            sub_region_2 sub_region_2_code                     place_id  \
# date
# 2020-01-01   Cumberland             42041  ChIJgWYAHnYeyYkR4YrBSt8OEcs
# 2020-01-01  Northampton             42095   ChIJexs0vPAWxIkRlPV5q6zFZ1
# 2020-01-01        Bucks             42017  ChIJHw5nt85GxIkRE6dc-_7kG54
# 2020-01-01         Erie             42049  ChIJRfAkQGh-LYgRRPHJjU87Btg
# 2020-01-01    Lancaster             42071  ChIJnRLnFlAfxokR1p1HPfkfGoU
#
#             symptom:Abdominal obesity  symptom:Abdominal pain  symptom:Acne  \
# date
# 2020-01-01                       2.58                    4.44          9.40
# 2020-01-01                       2.11                    3.86          6.76
# 2020-01-01                       2.19                    4.16          8.87
# 2020-01-01                       2.97                    5.83          8.63
# 2020-01-01                       2.18                    5.11          8.29
#
#             symptom:Alcoholism  symptom:Allergy  symptom:Anemia  \
# date
# 2020-01-01                6.29            11.15            1.66
# 2020-01-01                5.45             7.99            1.38
# 2020-01-01                5.90             8.86            1.57
# 2020-01-01                5.83             9.88            1.81
# 2020-01-01                5.21             9.14            1.53
#
#             symptom:Angina pectoris  ...  symptom:Type 2 diabetes  \
# date                                 ...
# 2020-01-01                     0.72  ...                     3.49
# 2020-01-01                     0.47  ...                     3.01
# 2020-01-01                     0.53  ...                     3.02
# 2020-01-01                     0.91  ...                     3.57
# 2020-01-01                     0.54  ...                     3.12
#
#             symptom:Urinary incontinence  symptom:Urinary tract infection  \
# date
# 2020-01-01                          1.17                             4.05
# 2020-01-01                          1.04                             3.38
# 2020-01-01                          1.13                             3.44
# 2020-01-01                          1.56                             3.90
# 2020-01-01                          1.11                             2.83
#
#             symptom:Uterine contraction  symptom:Vaginal discharge  \
# date
# 2020-01-01                         0.89                       2.22
# 2020-01-01                         0.80                       2.24
# 2020-01-01                         0.59                       1.99
# 2020-01-01                         0.54                       2.75
# 2020-01-01                         1.11                       2.07
#
#             symptom:Vertigo  symptom:Vomiting  symptom:Wart  \
# date
# 2020-01-01             0.97              4.77          1.33
# 2020-01-01             0.80              3.66          1.48
# 2020-01-01             1.20              4.01          1.05
# 2020-01-01             1.42              4.33          1.10
# 2020-01-01             1.04              4.33          0.88
#
#             symptom:Weight gain  symptom:Xeroderma
# date
# 2020-01-01                 3.55               2.88
# 2020-01-01                 3.23               2.26
# 2020-01-01                 3.03               2.32
# 2020-01-01                 3.59               2.32
# 2020-01-01                 3.21               2.26
#
# [5 rows x 132 columns]

# %%
#now we have 25 counties to deal with - woohoo!
dated_google['sub_region_2'].nunique()
# Out:
# 25

# %%
dated_google = dated_google.fillna(0)

# %%
symptoms = dated_google.iloc[:, 3:]

# %%
pd.plotting.scatter_matrix(symptoms, figsize=(10,10));

# %%
# https://www.youtube.com/watch?v=Lsue2gEM9D0
pca = PCA()
pca.fit(symptoms)
pca_data = pca.transform(symptoms)

# %%
plt.scatter(pca_data[:,0], pca_data[:,1]);

# %%
pca.components_
# Out:
# array([[-0.00573162,  0.00721025,  0.00478074, ..., -0.0026363 ,
#         -0.00649548,  0.00488926],
#        [ 0.03622737,  0.08062234,  0.01422294, ...,  0.03603249,
#          0.06478842, -0.02917009],
#        [-0.02245903,  0.01615624, -0.04070902, ..., -0.0134918 ,
#          0.00272736,  0.00763261],
#        ...,
#        [ 0.0140804 , -0.00975502,  0.00792829, ..., -0.57531234,
#         -0.01306809, -0.002491  ],
#        [ 0.00951729,  0.00921806, -0.00707432, ...,  0.08466648,
#         -0.00757347,  0.01223943],
#        [ 0.01472177,  0.00841824, -0.01172639, ...,  0.07376334,
#         -0.00843988,  0.01117173]])

# %%
per_var = np.round(pca.explained_variance_ratio_*100, decimals = 1)
labels = ['PC' + str(x) for x in range(1, len(per_var) + 1)]

plt.bar(x=range(1, len(per_var)+1), height = per_var, tick_label = labels)
plt.ylabel("Percentage of Explained Variance")
plt.xlabel("Principal Component")
plt.title("Scree Plot")
plt.show()
