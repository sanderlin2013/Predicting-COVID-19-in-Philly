# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
# imports

import pandas as pd 
import numpy as np
from datetime import datetime, timedelta
from sklearn.decomposition import PCA
from sklearn import preprocessing
import matplotlib.pyplot as plt

# %%
#bringing in our 4 dataframes 
public_data = pd.read_csv("COVID-19_Aggregate_Cases_Current_Weekly_County_Health.csv")
#google_data_2020 = pd.read_csv("2020_sub_region_1_daily_2020_US_Pennsylvania_daily_symptoms_dataset.csv",  dtype=str)
google_data_2021 = pd.read_csv("2021_sub_region_1_daily_2021_US_Pennsylvania_daily_symptoms_dataset(1).csv", dtype=str)
google_data_2022 = pd.read_csv("2022_sub_region_1_daily_2022_US_Pennsylvania_daily_symptoms_dataset(1).csv", dtype=str)

# %%
# consolidating our google data into one dataframe
google_dataframes = [google_data_2021, google_data_2022]
google_data = pd.concat(google_dataframes)
google_data.head()
# Out:
#   country_region_code country_region  sub_region_1 sub_region_1_code  \
# 0                  US  United States  Pennsylvania             US-PA
# 1                  US  United States  Pennsylvania             US-PA
# 2                  US  United States  Pennsylvania             US-PA
# 3                  US  United States  Pennsylvania             US-PA
# 4                  US  United States  Pennsylvania             US-PA
#
#   sub_region_2 sub_region_2_code                     place_id        date  \
# 0          NaN               NaN  ChIJieUyHiaALYgRPbQiUEchRsI  2021-01-01
# 1          NaN               NaN  ChIJieUyHiaALYgRPbQiUEchRsI  2021-01-02
# 2          NaN               NaN  ChIJieUyHiaALYgRPbQiUEchRsI  2021-01-03
# 3          NaN               NaN  ChIJieUyHiaALYgRPbQiUEchRsI  2021-01-04
# 4          NaN               NaN  ChIJieUyHiaALYgRPbQiUEchRsI  2021-01-05
#
#   symptom:Abdominal obesity symptom:Abdominal pain  ... symptom:Wart  \
# 0                      2.42                   4.41  ...         1.05
# 1                      2.48                   4.42  ...         1.12
# 2                      2.88                   4.46  ...         1.14
# 3                      2.87                   4.28  ...         1.16
# 4                       2.8                   4.17  ...         1.23
#
#   symptom:Water retention symptom:Weakness symptom:Weight gain symptom:Wheeze  \
# 0                    0.23             0.33                3.07           0.25
# 1                    0.25             0.38                3.26           0.26
# 2                    0.23             0.42                3.46           0.24
# 3                    0.24             0.46                 3.6           0.27
# 4                    0.25             0.43                3.61           0.26
#
#   symptom:Xeroderma symptom:Xerostomia symptom:Yawn symptom:hyperhidrosis  \
# 0              2.86               0.42         0.16                  0.37
# 1               3.0               0.45         0.17                  0.45
# 2              3.07               0.46         0.15                  0.48
# 3              2.61               0.44         0.19                   0.5
# 4              2.54               0.43         0.17                  0.56
#
#   symptom:pancreatitis
# 0                 0.32
# 1                 0.32
# 2                 0.34
# 3                 0.38
# 4                 0.38
#
# [5 rows x 430 columns]

# %%
#removing extraneous columns from our `google_data`
google_data.drop(columns=["country_region_code", "country_region", "sub_region_1",
                          "sub_region_1_code", "place_id"], inplace=True)

google_data.head()
# Out:
#   sub_region_2 sub_region_2_code        date symptom:Abdominal obesity  \
# 0          NaN               NaN  2021-01-01                      2.42
# 1          NaN               NaN  2021-01-02                      2.48
# 2          NaN               NaN  2021-01-03                      2.88
# 3          NaN               NaN  2021-01-04                      2.87
# 4          NaN               NaN  2021-01-05                       2.8
#
#   symptom:Abdominal pain symptom:Acne symptom:Actinic keratosis  \
# 0                   4.41         7.71                      0.23
# 1                   4.42         8.42                      0.24
# 2                   4.46         8.53                      0.26
# 3                   4.28         8.08                      0.29
# 4                   4.17         7.91                       0.3
#
#   symptom:Acute bronchitis symptom:Adrenal crisis symptom:Ageusia  ...  \
# 0                      0.2                    0.1            0.38  ...
# 1                     0.21                   0.11            0.38  ...
# 2                     0.22                   0.09            0.38  ...
# 3                     0.25                    0.1             0.3  ...
# 4                     0.22                   0.09            0.31  ...
#
#   symptom:Wart symptom:Water retention symptom:Weakness symptom:Weight gain  \
# 0         1.05                    0.23             0.33                3.07
# 1         1.12                    0.25             0.38                3.26
# 2         1.14                    0.23             0.42                3.46
# 3         1.16                    0.24             0.46                 3.6
# 4         1.23                    0.25             0.43                3.61
#
#   symptom:Wheeze symptom:Xeroderma symptom:Xerostomia symptom:Yawn  \
# 0           0.25              2.86               0.42         0.16
# 1           0.26               3.0               0.45         0.17
# 2           0.24              3.07               0.46         0.15
# 3           0.27              2.61               0.44         0.19
# 4           0.26              2.54               0.43         0.17
#
#   symptom:hyperhidrosis symptom:pancreatitis
# 0                  0.37                 0.32
# 1                  0.45                 0.32
# 2                  0.48                 0.34
# 3                   0.5                 0.38
# 4                  0.56                 0.38
#
# [5 rows x 425 columns]

# %%
# make the date our index, then sort by the date index
google_data['date']= pd.to_datetime(google_data['date'])
google_data.set_index('date', inplace=True)
google_data = google_data.sort_index()

# %%
google_data.head()
# Out:
#                sub_region_2 sub_region_2_code symptom:Abdominal obesity  \
# date
# 2021-01-01              NaN               NaN                      2.42
# 2021-01-01    Greene County             42059                       NaN
# 2021-01-01  Somerset County             42111                      2.61
# 2021-01-01     Blair County             42013                      3.43
# 2021-01-01    Fulton County             42057                       NaN
#
#            symptom:Abdominal pain symptom:Acne symptom:Actinic keratosis  \
# date
# 2021-01-01                   4.41         7.71                      0.23
# 2021-01-01                   5.82         7.28                       NaN
# 2021-01-01                   5.58          7.6                       NaN
# 2021-01-01                   4.88         8.19                       NaN
# 2021-01-01                    NaN          NaN                       NaN
#
#            symptom:Acute bronchitis symptom:Adrenal crisis symptom:Ageusia  \
# date
# 2021-01-01                      0.2                    0.1            0.38
# 2021-01-01                      NaN                    NaN             NaN
# 2021-01-01                      NaN                    NaN             NaN
# 2021-01-01                      NaN                    NaN             NaN
# 2021-01-01                      NaN                    NaN             NaN
#
#            symptom:Alcoholism  ... symptom:Wart symptom:Water retention  \
# date                           ...
# 2021-01-01               5.35  ...         1.05                    0.23
# 2021-01-01               4.61  ...          NaN                     NaN
# 2021-01-01               5.11  ...          NaN                     NaN
# 2021-01-01               6.27  ...         1.22                     NaN
# 2021-01-01                NaN  ...          NaN                     NaN
#
#            symptom:Weakness symptom:Weight gain symptom:Wheeze  \
# date
# 2021-01-01             0.33                3.07           0.25
# 2021-01-01              NaN                 NaN            NaN
# 2021-01-01              NaN                 NaN            NaN
# 2021-01-01              NaN                3.25            NaN
# 2021-01-01              NaN                 NaN            NaN
#
#            symptom:Xeroderma symptom:Xerostomia symptom:Yawn  \
# date
# 2021-01-01              2.86               0.42         0.16
# 2021-01-01               NaN                NaN          NaN
# 2021-01-01              2.85                NaN          NaN
# 2021-01-01              3.02                NaN          NaN
# 2021-01-01               NaN                NaN          NaN
#
#            symptom:hyperhidrosis symptom:pancreatitis
# date
# 2021-01-01                  0.37                 0.32
# 2021-01-01                   NaN                  NaN
# 2021-01-01                   NaN                  NaN
# 2021-01-01                   NaN                  NaN
# 2021-01-01                   NaN                  NaN
#
# [5 rows x 424 columns]

# %%
google_col = google_data.columns.to_list()
#symptom_col = google_col[2:]

# %%
#changing our symptoms columns dtype to float
google_data[google_col[2:]] = google_data[google_col[2:]].astype(float)

# %%
# checking for null values
google_data.isnull().sum()
# Out:
# sub_region_2                   682
# sub_region_2_code              682
# symptom:Abdominal obesity    17295
# symptom:Abdominal pain        4532
# symptom:Acne                  3126
#                              ...
# symptom:Xeroderma            17547
# symptom:Xerostomia           32439
# symptom:Yawn                 40129
# symptom:hyperhidrosis        31077
# symptom:pancreatitis         33806
# Length: 424, dtype: int64

# %%
google_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 44788 entries, 2021-01-01 to 2022-11-13
# Columns: 424 entries, sub_region_2 to symptom:pancreatitis
# dtypes: float64(422), object(2)
# memory usage: 145.2+ MB

# %%
google_philly = google_data[google_data.sub_region_2 == 'Philadelphia County']
google_philly
# Out:
#                    sub_region_2 sub_region_2_code  symptom:Abdominal obesity  \
# date
# 2021-01-01  Philadelphia County             42101                       2.34
# 2021-01-02  Philadelphia County             42101                       2.40
# 2021-01-03  Philadelphia County             42101                       2.62
# 2021-01-04  Philadelphia County             42101                       2.84
# 2021-01-05  Philadelphia County             42101                       2.77
# ...                         ...               ...                        ...
# 2022-11-09  Philadelphia County             42101                       1.34
# 2022-11-10  Philadelphia County             42101                       1.41
# 2022-11-11  Philadelphia County             42101                       1.33
# 2022-11-12  Philadelphia County             42101                       1.42
# 2022-11-13  Philadelphia County             42101                       1.51
#
#             symptom:Abdominal pain  symptom:Acne  symptom:Actinic keratosis  \
# date
# 2021-01-01                    4.07          8.03                       0.13
# 2021-01-02                    4.25          8.94                       0.20
# 2021-01-03                    4.23          8.99                       0.22
# 2021-01-04                    3.77          8.46                       0.23
# 2021-01-05                    3.68          8.24                       0.20
# ...                            ...           ...                        ...
# 2022-11-09                    3.44          6.12                       0.29
# 2022-11-10                    3.45          6.24                       0.21
# 2022-11-11                    3.56          6.30                       0.24
# 2022-11-12                    3.68          6.82                       0.22
# 2022-11-13                    3.81          6.93                       0.22
#
#             symptom:Acute bronchitis  symptom:Adrenal crisis  symptom:Ageusia  \
# date
# 2021-01-01                      0.16                    0.05             0.19
# 2021-01-02                      0.19                    0.11             0.29
# 2021-01-03                      0.19                    0.09             0.27
# 2021-01-04                      0.18                    0.06             0.23
# 2021-01-05                      0.20                    0.06             0.25
# ...                              ...                     ...              ...
# 2022-11-09                      0.62                    0.07             0.09
# 2022-11-10                      0.59                    0.14             0.07
# 2022-11-11                      0.47                    0.10             0.10
# 2022-11-12                      0.45                    0.10             0.06
# 2022-11-13                      0.48                    0.07             0.06
#
#             symptom:Alcoholism  ...  symptom:Wart  symptom:Water retention  \
# date                            ...
# 2021-01-01                4.82  ...          0.94                     0.21
# 2021-01-02                3.89  ...          1.01                     0.24
# 2021-01-03                3.64  ...          0.90                     0.20
# 2021-01-04                3.62  ...          0.93                     0.20
# 2021-01-05                3.94  ...          1.01                     0.23
# ...                        ...  ...           ...                      ...
# 2022-11-09                2.89  ...          1.05                     0.22
# 2022-11-10                3.18  ...          1.01                     0.20
# 2022-11-11                3.46  ...          0.97                     0.24
# 2022-11-12                3.54  ...          1.02                     0.21
# 2022-11-13                3.45  ...          0.96                     0.24
#
#             symptom:Weakness  symptom:Weight gain  symptom:Wheeze  \
# date
# 2021-01-01              0.26                 3.03            0.21
# 2021-01-02              0.34                 3.23            0.23
# 2021-01-03              0.41                 3.32            0.22
# 2021-01-04              0.44                 3.46            0.24
# 2021-01-05              0.45                 3.45            0.26
# ...                      ...                  ...             ...
# 2022-11-09              0.36                 2.62            0.38
# 2022-11-10              0.38                 2.60            0.28
# 2022-11-11              0.35                 2.51            0.35
# 2022-11-12              0.32                 2.63            0.25
# 2022-11-13              0.32                 2.48            0.29
#
#             symptom:Xeroderma  symptom:Xerostomia  symptom:Yawn  \
# date
# 2021-01-01               2.86                0.38          0.20
# 2021-01-02               3.04                0.47          0.15
# 2021-01-03               3.31                0.45          0.16
# 2021-01-04               2.81                0.40          0.21
# 2021-01-05               2.93                0.46          0.20
# ...                       ...                 ...           ...
# 2022-11-09               2.12                0.34          0.19
# 2022-11-10               2.06                0.35          0.13
# 2022-11-11               2.03                0.42          0.14
# 2022-11-12               2.25                0.35          0.14
# 2022-11-13               2.45                0.39          0.14
#
#             symptom:hyperhidrosis  symptom:pancreatitis
# date
# 2021-01-01                   0.40                  0.26
# 2021-01-02                   0.40                  0.20
# 2021-01-03                   0.52                  0.30
# 2021-01-04                   0.44                  0.24
# 2021-01-05                   0.56                  0.23
# ...                           ...                   ...
# 2022-11-09                   0.45                  0.31
# 2022-11-10                   0.39                  0.27
# 2022-11-11                   0.44                  0.28
# 2022-11-12                   0.47                  0.26
# 2022-11-13                   0.45                  0.26
#
# [682 rows x 424 columns]

# %%
#https://stackoverflow.com/questions/52044348/check-for-any-missing-dates-in-the-index
#checks for any missing dates! 
pd.date_range(start = '2021-01-01', end = '2022-11-13' ).difference(google_philly.index)
# Out:
# DatetimeIndex([], dtype='datetime64[ns]', freq=None)

# %%
# check for missing values in `google_philly`
google_philly.isnull().sum().sum()
# Out:
# 1779

# %%
google_philly.fillna(0, inplace = True)
# Out:
# /Users/rachelsanderlin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/frame.py:4317: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
google_philly.isnull().sum().sum()
# Out:
# 0

# %%
# get rid of county suffix 
google_philly = google_philly.applymap(lambda x: str(x).rstrip('County').rstrip())

# %%
google_philly.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 682 entries, 2021-01-01 to 2022-11-13
# Columns: 424 entries, sub_region_2 to symptom:pancreatitis
# dtypes: object(424)
# memory usage: 2.2+ MB

# %%
google_philly.drop(columns = ['sub_region_2', 'sub_region_2_code'], 
                                   inplace= True)

# %%
google_philly.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 682 entries, 2021-01-01 to 2022-11-13
# Columns: 422 entries, symptom:Abdominal obesity to symptom:pancreatitis
# dtypes: object(422)
# memory usage: 2.2+ MB

# %%
# start processing the public_data
public_data['Date'] = pd.to_datetime(public_data['Date'])
public_data.set_index('Date', inplace=True)
public_data = public_data.sort_index()

# %%
public_data.head()
# Out:
#            Jurisdiction  New Cases  7-day Average New Cases  \
# Date
# 2020-03-01    Lancaster          0                      NaN
# 2020-03-01        Blair          0                      NaN
# 2020-03-01  Susquehanna          0                      NaN
# 2020-03-01        Berks          0                      NaN
# 2020-03-01      Clinton          0                      NaN
#
#             Cumulative cases                            Population (2019)  \
# Date
# 2020-03-01                                           0             545724
# 2020-03-01                                           0             121829
# 2020-03-01                                           0              40328
# 2020-03-01                                           0             421164
# 2020-03-01                                           0              38632
#
#             New Case Rate  7-Day Average New Case Rate  Cumulative Case Rate  \
# Date
# 2020-03-01            0.0                          NaN                   0.0
# 2020-03-01            0.0                          NaN                   0.0
# 2020-03-01            0.0                          NaN                   0.0
# 2020-03-01            0.0                          NaN                   0.0
# 2020-03-01            0.0                          NaN                   0.0
#
#             County FIPS Code  Longitude   Latitude  \
# Date
# 2020-03-01             42071 -76.251388  40.045908
# 2020-03-01             42013 -78.349077  40.485550
# 2020-03-01             42115 -75.802503  41.820569
# 2020-03-01             42011 -75.930773  40.419396
# 2020-03-01             42035 -77.642838  41.232863
#
#                     Georeferenced Lat & Long
# Date
# 2020-03-01  POINT (-76.25138768 40.04590796)
# 2020-03-01  POINT (-78.34907687 40.48555024)
# 2020-03-01   POINT (-75.80250303 41.8205686)
# 2020-03-01  POINT (-75.93077327 40.41939635)
# 2020-03-01   POINT (-77.6428376 41.23286274)

# %%
public_philly = public_data[public_data.Jurisdiction == 'Philadelphia']
#making it so the dates will match when we join the two dataframes
public_philly = public_philly.loc["2021-01-01" : "2022-11-13"]
public_philly
# Out:
#             Jurisdiction  New Cases  7-day Average New Cases  \
# Date
# 2021-01-01  Philadelphia        392                    574.3
# 2021-01-02  Philadelphia        204                    571.6
# 2021-01-03  Philadelphia        322                    576.0
# 2021-01-04  Philadelphia        841                    579.3
# 2021-01-05  Philadelphia        699                    575.6
# ...                  ...        ...                      ...
# 2022-11-09  Philadelphia        196                    186.4
# 2022-11-10  Philadelphia        226                    179.1
# 2022-11-11  Philadelphia        117                    164.6
# 2022-11-12  Philadelphia        116                    159.0
# 2022-11-13  Philadelphia         78                    157.1
#
#             Cumulative cases                            Population (2019)  \
# Date
# 2021-01-01                                       95755            1584064
# 2021-01-02                                       95959            1584064
# 2021-01-03                                       96281            1584064
# 2021-01-04                                       97122            1584064
# 2021-01-05                                       97821            1584064
# ...                                                ...                ...
# 2022-11-09                                      371634            1584064
# 2022-11-10                                      371860            1584064
# 2022-11-11                                      371977            1584064
# 2022-11-12                                      372093            1584064
# 2022-11-13                                      372171            1584064
#
#             New Case Rate  7-Day Average New Case Rate  Cumulative Case Rate  \
# Date
# 2021-01-01           24.7                         36.3                6044.9
# 2021-01-02           12.9                         36.1                6057.8
# 2021-01-03           20.3                         36.4                6078.1
# 2021-01-04           53.1                         36.6                6131.2
# 2021-01-05           44.1                         36.3                6175.3
# ...                   ...                          ...                   ...
# 2022-11-09           12.4                         11.8               23460.8
# 2022-11-10           14.3                         11.3               23475.1
# 2022-11-11            7.4                         10.4               23482.4
# 2022-11-12            7.3                         10.0               23489.8
# 2022-11-13            4.9                          9.9               23494.7
#
#             County FIPS Code  Longitude   Latitude  \
# Date
# 2021-01-01             42101 -75.140236  40.004444
# 2021-01-02             42101 -75.140236  40.004444
# 2021-01-03             42101 -75.140236  40.004444
# 2021-01-04             42101 -75.140236  40.004444
# 2021-01-05             42101 -75.140236  40.004444
# ...                      ...        ...        ...
# 2022-11-09             42101 -75.140236  40.004444
# 2022-11-10             42101 -75.140236  40.004444
# 2022-11-11             42101 -75.140236  40.004444
# 2022-11-12             42101 -75.140236  40.004444
# 2022-11-13             42101 -75.140236  40.004444
#
#                   Georeferenced Lat & Long
# Date
# 2021-01-01  POINT (-75.140236 40.00444354)
# 2021-01-02  POINT (-75.140236 40.00444354)
# 2021-01-03  POINT (-75.140236 40.00444354)
# 2021-01-04  POINT (-75.140236 40.00444354)
# 2021-01-05  POINT (-75.140236 40.00444354)
# ...                                    ...
# 2022-11-09  POINT (-75.140236 40.00444354)
# 2022-11-10  POINT (-75.140236 40.00444354)
# 2022-11-11  POINT (-75.140236 40.00444354)
# 2022-11-12  POINT (-75.140236 40.00444354)
# 2022-11-13  POINT (-75.140236 40.00444354)
#
# [682 rows x 12 columns]

# %%
# no null values to deal with here
public_philly.isnull().sum().sum()
# Out:
# 0

# %%
# drop columns that aren't needed, 
#join data sets and decide on target variable
