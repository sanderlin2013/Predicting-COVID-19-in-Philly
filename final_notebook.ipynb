# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Predicting-Covid-Cases-From-Google-Search-Data:-A-Time-Series-Analysis" data-toc-modified-id="Predicting-Covid-Cases-From-Google-Search-Data:-A-Time-Series-Analysis-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Predicting Covid Cases From Google Search Data: A Time Series Analysis</a></span></li><li><span><a href="#Business-and-Data-Understanding" data-toc-modified-id="Business-and-Data-Understanding-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Business and Data Understanding</a></span><ul class="toc-item"><li><span><a href="#Business-Problem" data-toc-modified-id="Business-Problem-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Business Problem</a></span></li><li><span><a href="#Data" data-toc-modified-id="Data-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Data</a></span><ul class="toc-item"><li><span><a href="#Limitations-of-the-dataset:" data-toc-modified-id="Limitations-of-the-dataset:-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Limitations of the dataset:</a></span></li><li><span><a href="#Why-We-Used-This-Dataset" data-toc-modified-id="Why-We-Used-This-Dataset-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Why We Used This Dataset</a></span></li><li><span><a href="#Dataset-Size" data-toc-modified-id="Dataset-Size-2.2.3"><span class="toc-item-num">2.2.3&nbsp;&nbsp;</span>Dataset Size</a></span></li></ul></li></ul></li><li><span><a href="#Initial-Look-at-the-Data" data-toc-modified-id="Initial-Look-at-the-Data-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Initial Look at the Data</a></span><ul class="toc-item"><li><span><a href="#Imports" data-toc-modified-id="Imports-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Imports</a></span></li><li><span><a href="#Data-Preprocessing" data-toc-modified-id="Data-Preprocessing-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Data Preprocessing</a></span><ul class="toc-item"><li><span><a href="#Google-Search-Data" data-toc-modified-id="Google-Search-Data-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Google Search Data</a></span></li><li><span><a href="#Public-COVID-19-PA-Data" data-toc-modified-id="Public-COVID-19-PA-Data-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Public COVID-19 PA Data</a></span></li><li><span><a href="#Joining-the-Google-and-Public-COVID-19-Data" data-toc-modified-id="Joining-the-Google-and-Public-COVID-19-Data-3.2.3"><span class="toc-item-num">3.2.3&nbsp;&nbsp;</span>Joining the Google and Public COVID-19 Data</a></span></li></ul></li><li><span><a href="#Initial-Visualizations" data-toc-modified-id="Initial-Visualizations-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Initial Visualizations</a></span><ul class="toc-item"><li><span><a href="#Test-Train-Split:-Target-Variable" data-toc-modified-id="Test-Train-Split:-Target-Variable-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Test Train Split: Target Variable</a></span></li></ul></li></ul></li><li><span><a href="#Base-Model-of-the-Target-Variable" data-toc-modified-id="Base-Model-of-the-Target-Variable-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Base Model of the Target Variable</a></span></li><li><span><a href="#Multivariate-Time-Series-Model" data-toc-modified-id="Multivariate-Time-Series-Model-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Multivariate Time Series Model</a></span><ul class="toc-item"><li><span><a href="#PCA" data-toc-modified-id="PCA-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>PCA</a></span><ul class="toc-item"><li><span><a href="#Granger-Causality-Test" data-toc-modified-id="Granger-Causality-Test-5.1.1"><span class="toc-item-num">5.1.1&nbsp;&nbsp;</span>Granger Causality Test</a></span></li></ul></li><li><span><a href="#VAR-model" data-toc-modified-id="VAR-model-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>VAR model</a></span><ul class="toc-item"><li><span><a href="#Validation-Data-VAR-Model" data-toc-modified-id="Validation-Data-VAR-Model-5.2.1"><span class="toc-item-num">5.2.1&nbsp;&nbsp;</span>Validation Data VAR Model</a></span></li></ul></li></ul></li><li><span><a href="#Final-Model-Evaluation" data-toc-modified-id="Final-Model-Evaluation-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Final Model Evaluation</a></span></li><li><span><a href="#Conclusion" data-toc-modified-id="Conclusion-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Conclusion</a></span></li></ul></div>

# %% [markdown]
# # Predicting Covid Cases From Google Search Data: A Time Series Analysis

# %% [markdown]
# # Business and Data Understanding
#
# ## Business Problem
#
# The city of Philadelphia has been tracking it's COVID-19 cases since the beginning of the pandemic. They want to know if by looking into Google's COVID-19 related search data, it would be possible to predict (or at least find a correlation) between COVID-19 rates. If some kind of prediction can be made it would be useful to be able to prepare for spikes in COVID-19 cases and increase preventative measures (mask mandates, encouraging social distancing ect., warn hospitals) when needed.
#
# ## Data
# In order to do this analysis, there were two data sets that we put together.
#
# The independent variables were taken from [Google's Explore COVID-19 Symptoms Search Trends](https://pair-code.github.io/covid19_symptom_dataset/?country=IE). The data was downloaded from the USA region (sub region of Pennsylvania) at the daily resolution. All of the data from January 1st, 2020 through November 11th, 2022 was then collated into one data frame, containing 68,805 rows and 430 columns. This data had all been [scaled and normalized](https://storage.googleapis.com/gcp-public-data-symptom-search/COVID-19%20Search%20Trends%20symptoms%20dataset%20documentation%20.pdf) prior to being downloaded.
#
# The target variable was taken from [COVID-19 Data for Pennsylvania](https://www.health.pa.gov/topics/disease/coronavirus/pages/Cases.aspx). This data spanned from March 1st, 2020 until March 14, 2023 and included 75,412 rows and 12 columns.
#
# ### Limitations of the dataset:
# While these two datasets do included a fairly comprehensive list of the search terms and COVID-19 case counts, it does not include all of the possible relevant elements relevant to the rise and fall of COVID-19 cases - for example they doesn't take into account the proliferation of novel versions of the virus (e.g. delta, omicron, etc.). The dataset is also limited by time - [COVID-19 was only proclaimed a pandemic by the World Health Organization on March 11th, 2020](https://www.yalemedicine.org/news/covid-timeline). As such, it could be that better predictions will be available as more time passed, allowing for more time series data to be collected.
#
# ### Why We Used This Dataset
# As the initial inquiry was about if search trends could be used to predict COVID-19, we felt that this was a perfect place to start! All of the acquired data was free and publicly available.
#
# ### Dataset Size
# Initially, we had two datasets, one with **68,805** rows and **430** columns, the other with **75,412** rows and **12 columns**. After subsetting these datasets to include **only the Philadelphia region**, cleaning the data, and matching the dates of the datasets, we had **991** rows (representing from March 8th, 2020 to November 13th, 2022) and **423** columns.

# %% [markdown]
# # Initial Look at the Data
#
#
# ## Imports

# %%
# imports
import pmdarima as pm
import seaborn as sns
import pandas as pd
import numpy as np
from numpy import log
from datetime import datetime, timedelta
from statsmodels.tsa.stattools import grangercausalitytests, adfuller
from sklearn.decomposition import PCA
from sklearn import preprocessing
import matplotlib.pyplot as plt
# %matplotlib inline
import statsmodels.api as sm
plt.style.use('fivethirtyeight')
from scipy.stats import pearsonr
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.api import VAR
from statsmodels.tsa.statespace.varmax import VARMAX

# %%
# bringing in our 4 dataframes

public_data = pd.read_csv(
    "COVID-19_Aggregate_Cases_Current_Weekly_County_Health.csv")
google_data_2020 = pd.read_csv(
    "2020_sub_region_1_daily_2020_US_Pennsylvania_daily_symptoms_dataset.csv",  dtype=str)
google_data_2021 = pd.read_csv(
    "2021_sub_region_1_daily_2021_US_Pennsylvania_daily_symptoms_dataset(1).csv", dtype=str)
google_data_2022 = pd.read_csv(
    "2022_sub_region_1_daily_2022_US_Pennsylvania_daily_symptoms_dataset(1).csv", dtype=str)

# %% [markdown]
# ## Data Preprocessing
#
# ### Google Search Data
#
# Lets start by consolidating all of our separate Google .csv files into one data frame.

# %%
# consolidating the google data into one dataframe
google_dataframes = [google_data_2020, google_data_2021, google_data_2022]
google_data = pd.concat(google_dataframes)
google_data.head()
# Out:
#   country_region_code country_region  sub_region_1 sub_region_1_code
# 0                  US  United States  Pennsylvania             US-PA  \
# 1                  US  United States  Pennsylvania             US-PA
# 2                  US  United States  Pennsylvania             US-PA
# 3                  US  United States  Pennsylvania             US-PA
# 4                  US  United States  Pennsylvania             US-PA
#
#   sub_region_2 sub_region_2_code                     place_id        date
# 0          NaN               NaN  ChIJieUyHiaALYgRPbQiUEchRsI  2020-01-01  \
# 1          NaN               NaN  ChIJieUyHiaALYgRPbQiUEchRsI  2020-01-02
# 2          NaN               NaN  ChIJieUyHiaALYgRPbQiUEchRsI  2020-01-03
# 3          NaN               NaN  ChIJieUyHiaALYgRPbQiUEchRsI  2020-01-04
# 4          NaN               NaN  ChIJieUyHiaALYgRPbQiUEchRsI  2020-01-05
#
#   symptom:Abdominal obesity symptom:Abdominal pain  ... symptom:Wart
# 0                      2.37                   4.85  ...         1.22  \
# 1                      2.28                   4.74  ...         1.34
# 2                      2.04                   4.62  ...         1.23
# 3                      2.25                   4.83  ...         1.22
# 4                       2.5                    4.7  ...         1.19
#
#   symptom:Water retention symptom:Weakness symptom:Weight gain symptom:Wheeze
# 0                    0.24             0.34                3.29           0.38  \
# 1                    0.24              0.4                3.39           0.38
# 2                    0.23             0.38                3.17           0.34
# 3                    0.26              0.4                3.15           0.32
# 4                    0.25             0.37                3.38           0.34
#
#   symptom:Xeroderma symptom:Xerostomia symptom:Yawn symptom:hyperhidrosis
# 0              2.49               0.35         0.16                  0.47  \
# 1               2.4                0.4         0.16                  0.53
# 2              2.19               0.38         0.16                  0.51
# 3              2.46               0.39         0.17                  0.54
# 4               2.5               0.38         0.16                  0.53
#
#   symptom:pancreatitis
# 0                 0.38
# 1                 0.45
# 2                 0.41
# 3                 0.35
# 4                 0.36
#
# [5 rows x 430 columns]

# %%
# looking at the size and makeup of our dataframe
google_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 68805 entries, 0 to 20826
# Columns: 430 entries, country_region_code to symptom:pancreatitis
# dtypes: object(430)
# memory usage: 226.2+ MB

# %% [markdown]
# Now, lets extract *only* the data relevant to Philadelphia and clean up our dataset a bit.

# %%
google_philly = google_data[google_data.sub_region_2 == 'Philadelphia County']
google_philly.head()
# Out:
#       country_region_code country_region  sub_region_1 sub_region_1_code
# 17934                  US  United States  Pennsylvania             US-PA  \
# 17935                  US  United States  Pennsylvania             US-PA
# 17936                  US  United States  Pennsylvania             US-PA
# 17937                  US  United States  Pennsylvania             US-PA
# 17938                  US  United States  Pennsylvania             US-PA
#
#               sub_region_2 sub_region_2_code                     place_id
# 17934  Philadelphia County             42101  ChIJ60u11Ni3xokRhBCHQtzJmsM  \
# 17935  Philadelphia County             42101  ChIJ60u11Ni3xokRhBCHQtzJmsM
# 17936  Philadelphia County             42101  ChIJ60u11Ni3xokRhBCHQtzJmsM
# 17937  Philadelphia County             42101  ChIJ60u11Ni3xokRhBCHQtzJmsM
# 17938  Philadelphia County             42101  ChIJ60u11Ni3xokRhBCHQtzJmsM
#
#              date symptom:Abdominal obesity symptom:Abdominal pain  ...
# 17934  2020-01-01                      2.35                   4.46  ...  \
# 17935  2020-01-02                      2.37                   4.17  ...
# 17936  2020-01-03                      2.13                   4.18  ...
# 17937  2020-01-04                      2.37                    4.5  ...
# 17938  2020-01-05                      2.36                   4.12  ...
#
#       symptom:Wart symptom:Water retention symptom:Weakness
# 17934         1.09                     0.2             0.31  \
# 17935         1.14                    0.19             0.37
# 17936         1.08                    0.17             0.32
# 17937          1.1                    0.18             0.37
# 17938         1.12                    0.21             0.28
#
#       symptom:Weight gain symptom:Wheeze symptom:Xeroderma symptom:Xerostomia
# 17934                2.95           0.32              2.55               0.31  \
# 17935                3.01           0.27              2.63               0.34
# 17936                2.95           0.29              2.46                0.3
# 17937                3.26           0.28              2.78               0.42
# 17938                3.21           0.25              2.82               0.35
#
#       symptom:Yawn symptom:hyperhidrosis symptom:pancreatitis
# 17934         0.19                  0.37                 0.25
# 17935         0.14                   0.5                 0.34
# 17936         0.18                  0.51                  0.3
# 17937         0.24                  0.48                 0.27
# 17938          0.2                  0.49                 0.24
#
# [5 rows x 430 columns]

# %%
# removing extraneous columns from our `google_data`
google_philly.drop(columns=["sub_region_2", "sub_region_2_code","country_region_code", "country_region", "sub_region_1",
                          "sub_region_1_code", "place_id"], inplace=True)

google_philly.head()
# Out:
# /var/folders/nz/h8wmnpz55qb3srn4_mj451lc0000gn/T/ipykernel_52425/101459141.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   google_philly.drop(columns=["sub_region_2", "sub_region_2_code","country_region_code", "country_region", "sub_region_1",
#              date symptom:Abdominal obesity symptom:Abdominal pain
# 17934  2020-01-01                      2.35                   4.46  \
# 17935  2020-01-02                      2.37                   4.17
# 17936  2020-01-03                      2.13                   4.18
# 17937  2020-01-04                      2.37                    4.5
# 17938  2020-01-05                      2.36                   4.12
#
#       symptom:Acne symptom:Actinic keratosis symptom:Acute bronchitis
# 17934         7.76                      0.19                     0.62  \
# 17935         8.13                      0.24                     0.66
# 17936         7.57                      0.24                     0.78
# 17937         8.85                      0.16                     0.69
# 17938         8.58                      0.07                     0.62
#
#       symptom:Adrenal crisis symptom:Ageusia symptom:Alcoholism
# 17934                   0.09             NaN               5.11  \
# 17935                   0.05             NaN               4.35
# 17936                   0.07            0.06               4.01
# 17937                   0.09             NaN               4.38
# 17938                   0.07             NaN               3.82
#
#       symptom:Allergic conjunctivitis  ... symptom:Wart
# 17934                             NaN  ...         1.09  \
# 17935                             NaN  ...         1.14
# 17936                            0.09  ...         1.08
# 17937                            0.09  ...          1.1
# 17938                            0.08  ...         1.12
#
#       symptom:Water retention symptom:Weakness symptom:Weight gain
# 17934                     0.2             0.31                2.95  \
# 17935                    0.19             0.37                3.01
# 17936                    0.17             0.32                2.95
# 17937                    0.18             0.37                3.26
# 17938                    0.21             0.28                3.21
#
#       symptom:Wheeze symptom:Xeroderma symptom:Xerostomia symptom:Yawn
# 17934           0.32              2.55               0.31         0.19  \
# 17935           0.27              2.63               0.34         0.14
# 17936           0.29              2.46                0.3         0.18
# 17937           0.28              2.78               0.42         0.24
# 17938           0.25              2.82               0.35          0.2
#
#       symptom:hyperhidrosis symptom:pancreatitis
# 17934                  0.37                 0.25
# 17935                   0.5                 0.34
# 17936                  0.51                  0.3
# 17937                  0.48                 0.27
# 17938                  0.49                 0.24
#
# [5 rows x 423 columns]

# %%
# make the date our index, then sort by the date index
google_philly['date'] = pd.to_datetime(google_philly['date'])
google_philly.set_index('date', inplace=True)
google_philly= google_philly.sort_index()
# Out:
# /var/folders/nz/h8wmnpz55qb3srn4_mj451lc0000gn/T/ipykernel_52425/2561510202.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   google_philly['date'] = pd.to_datetime(google_philly['date'])

# %%
google_philly.head()
# Out:
#            symptom:Abdominal obesity symptom:Abdominal pain symptom:Acne
# date
# 2020-01-01                      2.35                   4.46         7.76  \
# 2020-01-02                      2.37                   4.17         8.13
# 2020-01-03                      2.13                   4.18         7.57
# 2020-01-04                      2.37                    4.5         8.85
# 2020-01-05                      2.36                   4.12         8.58
#
#            symptom:Actinic keratosis symptom:Acute bronchitis
# date
# 2020-01-01                      0.19                     0.62  \
# 2020-01-02                      0.24                     0.66
# 2020-01-03                      0.24                     0.78
# 2020-01-04                      0.16                     0.69
# 2020-01-05                      0.07                     0.62
#
#            symptom:Adrenal crisis symptom:Ageusia symptom:Alcoholism
# date
# 2020-01-01                   0.09             NaN               5.11  \
# 2020-01-02                   0.05             NaN               4.35
# 2020-01-03                   0.07            0.06               4.01
# 2020-01-04                   0.09             NaN               4.38
# 2020-01-05                   0.07             NaN               3.82
#
#            symptom:Allergic conjunctivitis symptom:Allergy  ... symptom:Wart
# date                                                        ...
# 2020-01-01                             NaN             7.7  ...         1.09  \
# 2020-01-02                             NaN            9.17  ...         1.14
# 2020-01-03                            0.09            8.72  ...         1.08
# 2020-01-04                            0.09            8.07  ...          1.1
# 2020-01-05                            0.08            8.24  ...         1.12
#
#            symptom:Water retention symptom:Weakness symptom:Weight gain
# date
# 2020-01-01                     0.2             0.31                2.95  \
# 2020-01-02                    0.19             0.37                3.01
# 2020-01-03                    0.17             0.32                2.95
# 2020-01-04                    0.18             0.37                3.26
# 2020-01-05                    0.21             0.28                3.21
#
#            symptom:Wheeze symptom:Xeroderma symptom:Xerostomia symptom:Yawn
# date
# 2020-01-01           0.32              2.55               0.31         0.19  \
# 2020-01-02           0.27              2.63               0.34         0.14
# 2020-01-03           0.29              2.46                0.3         0.18
# 2020-01-04           0.28              2.78               0.42         0.24
# 2020-01-05           0.25              2.82               0.35          0.2
#
#            symptom:hyperhidrosis symptom:pancreatitis
# date
# 2020-01-01                  0.37                 0.25
# 2020-01-02                   0.5                 0.34
# 2020-01-03                  0.51                  0.3
# 2020-01-04                  0.48                 0.27
# 2020-01-05                  0.49                 0.24
#
# [5 rows x 422 columns]

# %%
# changing all our variable types from objects to float
google_philly = google_philly.astype('float')

# %%
# https://stackoverflow.com/questions/52044348/check-for-any-missing-dates-in-the-index

# checking for any missing dates!
pd.date_range(start='2020-01-01',
              end='2022-11-13').difference(google_philly.index)
# Out:
# DatetimeIndex([], dtype='datetime64[ns]', freq='D')

# %%
# check for missing values in `google_philly`
google_philly.isnull().sum().sum()
# Out:
# 3176

# %%
# checking for 0 in the whole data frame - we don't find any, so lets use 0 as the new value for our NaN's
(google_philly == 0).any().sum()
# Out:
# 0

# %%
# turning our NaN's to 0's
google_philly.fillna(0, inplace=True)

# %%
# checking for NaN's after our transformation
google_philly.isnull().sum().sum()
# Out:
# 0

# %%
# code from https://stackoverflow.com/questions/55679401/remove-prefix-or-suffix-substring-from-column-headers-in-pandas

# removing 'symptom:' prefix from all our symptoms
google_philly.columns = google_philly.columns.map(lambda x: x.removeprefix('symptom:'))

# %%
google_philly.head()
# Out:
#             Abdominal obesity  Abdominal pain  Acne  Actinic keratosis
# date
# 2020-01-01               2.35            4.46  7.76               0.19  \
# 2020-01-02               2.37            4.17  8.13               0.24
# 2020-01-03               2.13            4.18  7.57               0.24
# 2020-01-04               2.37            4.50  8.85               0.16
# 2020-01-05               2.36            4.12  8.58               0.07
#
#             Acute bronchitis  Adrenal crisis  Ageusia  Alcoholism
# date
# 2020-01-01              0.62            0.09     0.00        5.11  \
# 2020-01-02              0.66            0.05     0.00        4.35
# 2020-01-03              0.78            0.07     0.06        4.01
# 2020-01-04              0.69            0.09     0.00        4.38
# 2020-01-05              0.62            0.07     0.00        3.82
#
#             Allergic conjunctivitis  Allergy  ...  Wart  Water retention
# date                                          ...
# 2020-01-01                     0.00     7.70  ...  1.09             0.20  \
# 2020-01-02                     0.00     9.17  ...  1.14             0.19
# 2020-01-03                     0.09     8.72  ...  1.08             0.17
# 2020-01-04                     0.09     8.07  ...  1.10             0.18
# 2020-01-05                     0.08     8.24  ...  1.12             0.21
#
#             Weakness  Weight gain  Wheeze  Xeroderma  Xerostomia  Yawn
# date
# 2020-01-01      0.31         2.95    0.32       2.55        0.31  0.19  \
# 2020-01-02      0.37         3.01    0.27       2.63        0.34  0.14
# 2020-01-03      0.32         2.95    0.29       2.46        0.30  0.18
# 2020-01-04      0.37         3.26    0.28       2.78        0.42  0.24
# 2020-01-05      0.28         3.21    0.25       2.82        0.35  0.20
#
#             hyperhidrosis  pancreatitis
# date
# 2020-01-01           0.37          0.25
# 2020-01-02           0.50          0.34
# 2020-01-03           0.51          0.30
# 2020-01-04           0.48          0.27
# 2020-01-05           0.49          0.24
#
# [5 rows x 422 columns]

# %%
# I used this code to get a list of all the symptoms columns, so I could go over them one by one and decide which
# ones to include for further analysis. The symptoms were selected based on how well they matched the CDC's list
# of recommended symptoms to test for COVID-19.
# (https://www.cdc.gov/coronavirus/2019-ncov/symptoms-testing/symptoms.html)

# symptoms = pd.DataFrame()
# symptoms['symptoms']= google_philly.columns.values
# symptoms.to_csv("symptoms.csv")

# %%
google_philly.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1048 entries, 2020-01-01 to 2022-11-13
# Columns: 422 entries, Abdominal obesity to pancreatitis
# dtypes: float64(422)
# memory usage: 3.4 MB

# %% [markdown]
# ### Public COVID-19 PA Data

# %%
# start processing the public_data - make the `Date` the index
public_data['Date'] = pd.to_datetime(public_data['Date'])
public_data.set_index('Date', inplace=True)
public_data = public_data.sort_index()

# %%
# looking at the data
public_data
# Out:
#            Jurisdiction  New Cases  7-day Average New Cases
# Date
# 2020-03-01    Lancaster          0                      NaN  \
# 2020-03-01        Blair          0                      NaN
# 2020-03-01  Susquehanna          0                      NaN
# 2020-03-01        Berks          0                      NaN
# 2020-03-01      Clinton          0                      NaN
# ...                 ...        ...                      ...
# 2023-03-14      Dauphin         15                     16.6
# 2023-03-14     Crawford         14                     12.3
# 2023-03-14      Venango          4                      4.4
# 2023-03-14      Luzerne         27                     23.6
# 2023-03-14    Lancaster         48                     37.1
#
#             Cumulative cases                            Population (2019)
# Date
# 2020-03-01                                           0             545724  \
# 2020-03-01                                           0             121829
# 2020-03-01                                           0              40328
# 2020-03-01                                           0             421164
# 2020-03-01                                           0              38632
# ...                                                ...                ...
# 2023-03-14                                       72765             278299
# 2023-03-14                                       25018              84629
# 2023-03-14                                       13866              50668
# 2023-03-14                                       95034             317417
# 2023-03-14                                      151152             545724
#
#             New Case Rate  7-Day Average New Case Rate  Cumulative Case Rate
# Date
# 2020-03-01            0.0                          NaN                   0.0  \
# 2020-03-01            0.0                          NaN                   0.0
# 2020-03-01            0.0                          NaN                   0.0
# 2020-03-01            0.0                          NaN                   0.0
# 2020-03-01            0.0                          NaN                   0.0
# ...                   ...                          ...                   ...
# 2023-03-14            5.4                          6.0               26146.3
# 2023-03-14           16.5                         14.5               29562.0
# 2023-03-14            7.9                          8.7               27366.4
# 2023-03-14            8.5                          7.4               29939.8
# 2023-03-14            8.8                          6.8               27697.5
#
#             County FIPS Code  Longitude   Latitude
# Date
# 2020-03-01             42071 -76.251388  40.045908  \
# 2020-03-01             42013 -78.349077  40.485550
# 2020-03-01             42115 -75.802503  41.820569
# 2020-03-01             42011 -75.930773  40.419396
# 2020-03-01             42035 -77.642838  41.232863
# ...                      ...        ...        ...
# 2023-03-14             42043 -76.779606  40.419746
# 2023-03-14             42039 -80.113211  41.685469
# 2023-03-14             42121 -79.762866  41.403413
# 2023-03-14             42079 -75.991996  41.178364
# 2023-03-14             42071 -76.251388  40.045908
#
#                     Georeferenced Lat & Long
# Date
# 2020-03-01  POINT (-76.25138768 40.04590796)
# 2020-03-01  POINT (-78.34907687 40.48555024)
# 2020-03-01   POINT (-75.80250303 41.8205686)
# 2020-03-01  POINT (-75.93077327 40.41939635)
# 2020-03-01   POINT (-77.6428376 41.23286274)
# ...                                      ...
# 2023-03-14  POINT (-76.77960568 40.41974636)
# 2023-03-14  POINT (-80.11321083 41.68546907)
# 2023-03-14  POINT (-79.76286561 41.40341259)
# 2023-03-14   POINT (-75.9919961 41.17836439)
# 2023-03-14  POINT (-76.25138768 40.04590796)
#
# [75412 rows x 12 columns]

# %%
# subsetting the data to only include Philadelphia
public_philly = public_data[public_data.Jurisdiction == 'Philadelphia']
# making it so the dates will match when we join the two dataframes
public_philly = public_philly.loc[: "2022-11-16"]
# looking at the data again
public_philly
# Out:
#             Jurisdiction  New Cases  7-day Average New Cases
# Date
# 2020-03-01  Philadelphia          0                      NaN  \
# 2020-03-02  Philadelphia          0                      NaN
# 2020-03-03  Philadelphia          0                      NaN
# 2020-03-04  Philadelphia          0                      NaN
# 2020-03-05  Philadelphia          0                      NaN
# ...                  ...        ...                      ...
# 2022-11-12  Philadelphia        116                    159.0
# 2022-11-13  Philadelphia         78                    157.1
# 2022-11-14  Philadelphia        165                    158.1
# 2022-11-15  Philadelphia        171                    152.7
# 2022-11-16  Philadelphia        203                    153.7
#
#             Cumulative cases                            Population (2019)
# Date
# 2020-03-01                                           0            1584064  \
# 2020-03-02                                           0            1584064
# 2020-03-03                                           0            1584064
# 2020-03-04                                           0            1584064
# 2020-03-05                                           0            1584064
# ...                                                ...                ...
# 2022-11-12                                      372093            1584064
# 2022-11-13                                      372171            1584064
# 2022-11-14                                      372336            1584064
# 2022-11-15                                      372507            1584064
# 2022-11-16                                      372710            1584064
#
#             New Case Rate  7-Day Average New Case Rate  Cumulative Case Rate
# Date
# 2020-03-01            0.0                          NaN                   0.0  \
# 2020-03-02            0.0                          NaN                   0.0
# 2020-03-03            0.0                          NaN                   0.0
# 2020-03-04            0.0                          NaN                   0.0
# 2020-03-05            0.0                          NaN                   0.0
# ...                   ...                          ...                   ...
# 2022-11-12            7.3                         10.0               23489.8
# 2022-11-13            4.9                          9.9               23494.7
# 2022-11-14           10.4                         10.0               23505.1
# 2022-11-15           10.8                          9.6               23515.9
# 2022-11-16           12.8                          9.7               23528.7
#
#             County FIPS Code  Longitude   Latitude
# Date
# 2020-03-01             42101 -75.140236  40.004444  \
# 2020-03-02             42101 -75.140236  40.004444
# 2020-03-03             42101 -75.140236  40.004444
# 2020-03-04             42101 -75.140236  40.004444
# 2020-03-05             42101 -75.140236  40.004444
# ...                      ...        ...        ...
# 2022-11-12             42101 -75.140236  40.004444
# 2022-11-13             42101 -75.140236  40.004444
# 2022-11-14             42101 -75.140236  40.004444
# 2022-11-15             42101 -75.140236  40.004444
# 2022-11-16             42101 -75.140236  40.004444
#
#                   Georeferenced Lat & Long
# Date
# 2020-03-01  POINT (-75.140236 40.00444354)
# 2020-03-02  POINT (-75.140236 40.00444354)
# 2020-03-03  POINT (-75.140236 40.00444354)
# 2020-03-04  POINT (-75.140236 40.00444354)
# 2020-03-05  POINT (-75.140236 40.00444354)
# ...                                    ...
# 2022-11-12  POINT (-75.140236 40.00444354)
# 2022-11-13  POINT (-75.140236 40.00444354)
# 2022-11-14  POINT (-75.140236 40.00444354)
# 2022-11-15  POINT (-75.140236 40.00444354)
# 2022-11-16  POINT (-75.140236 40.00444354)
#
# [991 rows x 12 columns]

# %% [markdown]
# ### Joining the Google and Public COVID-19 Data

# %%
google_philly = google_philly.loc["2020-03-01" : "2022-11-16"]

# %% [markdown]
# After trying both the `New Cases` and the `7-day Average New Cases` as the target variable, I decided to use the `7-day Average New Cases` as it represents the rolling mean version of the data, and after running both models, it had a lower error rate according to all metrics (RMSE, MAE, MAPE).

# %%
# join data sets and decide on target variable
philly_data = pd.concat([google_philly, public_philly['7-day Average New Cases']], axis=1).dropna()
# '7-day Average New Cases' is too long - I renamed it as 'Target' insteas
philly_data.rename(columns={'7-day Average New Cases': 'Target'}, inplace=True)
target = philly_data['Target']
symptoms = philly_data.drop(['Target'], axis = 1)

# %%
symptoms
# Out:
#             Abdominal obesity  Abdominal pain  Acne  Actinic keratosis
# 2020-03-08               2.55            3.95  8.81               0.22  \
# 2020-03-09               2.09            4.02  7.45               0.23
# 2020-03-10               2.10            3.88  7.47               0.20
# 2020-03-11               1.97            3.76  7.01               0.20
# 2020-03-12               1.42            3.44  6.45               0.19
# ...                       ...             ...   ...                ...
# 2022-11-09               1.34            3.44  6.12               0.29
# 2022-11-10               1.41            3.45  6.24               0.21
# 2022-11-11               1.33            3.56  6.30               0.24
# 2022-11-12               1.42            3.68  6.82               0.22
# 2022-11-13               1.51            3.81  6.93               0.22
#
#             Acute bronchitis  Adrenal crisis  Ageusia  Alcoholism
# 2020-03-08              0.45            0.09     0.00        3.60  \
# 2020-03-09              0.62            0.12     0.05        3.64
# 2020-03-10              0.65            0.09     0.06        3.51
# 2020-03-11              0.76            0.09     0.04        3.59
# 2020-03-12              0.72            0.08     0.04        3.40
# ...                      ...             ...      ...         ...
# 2022-11-09              0.62            0.07     0.09        2.89
# 2022-11-10              0.59            0.14     0.07        3.18
# 2022-11-11              0.47            0.10     0.10        3.46
# 2022-11-12              0.45            0.10     0.06        3.54
# 2022-11-13              0.48            0.07     0.06        3.45
#
#             Allergic conjunctivitis  Allergy  ...  Wart  Water retention
# 2020-03-08                     0.00     9.20  ...  1.07             0.29  \
# 2020-03-09                     0.09    11.29  ...  1.05             0.28
# 2020-03-10                     0.09    11.45  ...  0.99             0.22
# 2020-03-11                     0.07    11.44  ...  1.01             0.25
# 2020-03-12                     0.11    11.51  ...  0.85             0.24
# ...                             ...      ...  ...   ...              ...
# 2022-11-09                     0.08     9.44  ...  1.05             0.22
# 2022-11-10                     0.07     9.37  ...  1.01             0.20
# 2022-11-11                     0.04     9.07  ...  0.97             0.24
# 2022-11-12                     0.07     9.30  ...  1.02             0.21
# 2022-11-13                     0.07     8.20  ...  0.96             0.24
#
#             Weakness  Weight gain  Wheeze  Xeroderma  Xerostomia  Yawn
# 2020-03-08      0.35         2.97    0.33       3.23        0.43  0.30  \
# 2020-03-09      0.45         2.90    0.33       2.62        0.42  0.15
# 2020-03-10      0.48         3.01    0.32       2.33        0.42  0.13
# 2020-03-11      0.54         2.65    0.33       2.39        0.32  0.10
# 2020-03-12      0.63         2.19    0.38       1.99        0.39  0.14
# ...              ...          ...     ...        ...         ...   ...
# 2022-11-09      0.36         2.62    0.38       2.12        0.34  0.19
# 2022-11-10      0.38         2.60    0.28       2.06        0.35  0.13
# 2022-11-11      0.35         2.51    0.35       2.03        0.42  0.14
# 2022-11-12      0.32         2.63    0.25       2.25        0.35  0.14
# 2022-11-13      0.32         2.48    0.29       2.45        0.39  0.14
#
#             hyperhidrosis  pancreatitis
# 2020-03-08           0.46          0.25
# 2020-03-09           0.51          0.22
# 2020-03-10           0.54          0.26
# 2020-03-11           0.51          0.27
# 2020-03-12           0.39          0.18
# ...                   ...           ...
# 2022-11-09           0.45          0.31
# 2022-11-10           0.39          0.27
# 2022-11-11           0.44          0.28
# 2022-11-12           0.47          0.26
# 2022-11-13           0.45          0.26
#
# [981 rows x 422 columns]

# %%
philly_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 981 entries, 2020-03-08 to 2022-11-13
# Freq: D
# Columns: 423 entries, Abdominal obesity to Target
# dtypes: float64(423)
# memory usage: 3.2 MB

# %%
philly_data.describe()
# Out:
#        Abdominal obesity  Abdominal pain        Acne  Actinic keratosis
# count         981.000000      981.000000  981.000000         981.000000  \
# mean            2.126891        3.670204    7.592018           0.251407
# std             0.512854        0.313704    0.989178           0.053219
# min             0.960000        2.590000    5.340000           0.110000
# 25%             1.750000        3.500000    6.850000           0.210000
# 50%             2.100000        3.640000    7.530000           0.250000
# 75%             2.500000        3.820000    8.160000           0.290000
# max             3.730000        8.400000   12.340000           0.480000
#
#        Acute bronchitis  Adrenal crisis     Ageusia  Alcoholism
# count        981.000000      981.000000  981.000000  981.000000  \
# mean           0.276901        0.087238    0.135984    3.500499
# std            0.122890        0.033182    0.093180    0.409302
# min            0.000000        0.000000    0.000000    2.600000
# 25%            0.190000        0.070000    0.070000    3.320000
# 50%            0.250000        0.090000    0.110000    3.460000
# 75%            0.350000        0.100000    0.170000    3.610000
# max            0.760000        0.420000    0.720000    8.790000
#
#        Allergic conjunctivitis     Allergy  ...  Water retention    Weakness
# count               981.000000  981.000000  ...       981.000000  981.000000  \
# mean                  0.059276    9.737217  ...         0.254801    0.391692
# std                   0.042301    1.428607  ...         0.053122    0.060154
# min                   0.000000    6.390000  ...         0.120000    0.240000
# 25%                   0.040000    8.750000  ...         0.220000    0.350000
# 50%                   0.060000    9.640000  ...         0.250000    0.390000
# 75%                   0.080000   10.490000  ...         0.290000    0.430000
# max                   0.340000   16.150000  ...         0.520000    0.670000
#
#        Weight gain      Wheeze   Xeroderma  Xerostomia        Yawn
# count   981.000000  981.000000  981.000000  981.000000  981.000000  \
# mean      2.981590    0.248522    2.436483    0.370010    0.158756
# std       0.338609    0.052368    0.513752    0.049852    0.028239
# min       1.950000    0.100000    1.490000    0.210000    0.070000
# 25%       2.750000    0.220000    2.090000    0.340000    0.140000
# 50%       3.000000    0.240000    2.310000    0.370000    0.160000
# 75%       3.220000    0.280000    2.680000    0.400000    0.180000
# max       3.930000    0.480000    5.870000    0.560000    0.300000
#
#        hyperhidrosis  pancreatitis       Target
# count     981.000000    981.000000   981.000000
# mean        0.490357      0.276881   378.971560
# std         0.117776      0.209378   494.922732
# min         0.260000      0.140000     0.100000
# 25%         0.410000      0.230000   151.900000
# 50%         0.470000      0.260000   267.400000
# 75%         0.540000      0.290000   410.700000
# max         2.180000      6.040000  4047.700000
#
# [8 rows x 423 columns]

# %% [markdown]
# ## Initial Visualizations

# %%
# looking at the distribution of our target variable
target.hist(bins=100, figsize=(16, 8), alpha=0.5,
            edgecolor="black", linewidth=2)
plt.title(
    '7-Day Average COVID Cases in Philadelphia ', fontsize=20)
plt.xlabel('Days')
plt.ylabel('Number of Confimed Cases', fontsize=20);

# %% [markdown]
# ### Test Train Split: Target Variable

# %%
#this will leave us with 20 days in our test set, and 10 in our validation set
cutoff_test = 30
cutoff_val = 10

X_train = symptoms[:-cutoff_test]
X_test = symptoms[-cutoff_test: -cutoff_val]
X_val = symptoms[-cutoff_val:]

y_train = target[:-cutoff_test]
y_test = target[-cutoff_test: -cutoff_val]
y_val = target[-cutoff_val:]

# %%
y_test
# Out:
# 2022-10-15    191.3
# 2022-10-16    182.6
# 2022-10-17    205.7
# 2022-10-18    184.1
# 2022-10-19    188.3
# 2022-10-20    173.9
# 2022-10-21    165.0
# 2022-10-22    169.3
# 2022-10-23    176.4
# 2022-10-24    176.9
# 2022-10-25    176.3
# 2022-10-26    176.1
# 2022-10-27    176.1
# 2022-10-28    186.1
# 2022-10-29    185.6
# 2022-10-30    187.7
# 2022-10-31    179.4
# 2022-11-01    181.9
# 2022-11-02    178.4
# 2022-11-03    187.6
# Freq: D, Name: Target, dtype: float64

# %%
X_train.head()
# Out:
#             Abdominal obesity  Abdominal pain  Acne  Actinic keratosis
# 2020-03-08               2.55            3.95  8.81               0.22  \
# 2020-03-09               2.09            4.02  7.45               0.23
# 2020-03-10               2.10            3.88  7.47               0.20
# 2020-03-11               1.97            3.76  7.01               0.20
# 2020-03-12               1.42            3.44  6.45               0.19
#
#             Acute bronchitis  Adrenal crisis  Ageusia  Alcoholism
# 2020-03-08              0.45            0.09     0.00        3.60  \
# 2020-03-09              0.62            0.12     0.05        3.64
# 2020-03-10              0.65            0.09     0.06        3.51
# 2020-03-11              0.76            0.09     0.04        3.59
# 2020-03-12              0.72            0.08     0.04        3.40
#
#             Allergic conjunctivitis  Allergy  ...  Wart  Water retention
# 2020-03-08                     0.00     9.20  ...  1.07             0.29  \
# 2020-03-09                     0.09    11.29  ...  1.05             0.28
# 2020-03-10                     0.09    11.45  ...  0.99             0.22
# 2020-03-11                     0.07    11.44  ...  1.01             0.25
# 2020-03-12                     0.11    11.51  ...  0.85             0.24
#
#             Weakness  Weight gain  Wheeze  Xeroderma  Xerostomia  Yawn
# 2020-03-08      0.35         2.97    0.33       3.23        0.43  0.30  \
# 2020-03-09      0.45         2.90    0.33       2.62        0.42  0.15
# 2020-03-10      0.48         3.01    0.32       2.33        0.42  0.13
# 2020-03-11      0.54         2.65    0.33       2.39        0.32  0.10
# 2020-03-12      0.63         2.19    0.38       1.99        0.39  0.14
#
#             hyperhidrosis  pancreatitis
# 2020-03-08           0.46          0.25
# 2020-03-09           0.51          0.22
# 2020-03-10           0.54          0.26
# 2020-03-11           0.51          0.27
# 2020-03-12           0.39          0.18
#
# [5 rows x 422 columns]

# %%
ax = public_philly['New Cases'].plot(figsize=(20, 10), linewidth=3)
plt.title('New Daily COVID-19 Cases in Philadelphia', fontsize=30);

# %%
ax = target.plot(figsize=(20, 10), linewidth=3)
plt.title('7-day Average New COVID-19 Cases in Philadelphia', fontsize=30);

# %% [markdown]
# # Base Model of the Target Variable
# Now that we've seen the target variable, lets check for stationarity.

# %%
# Dicky Fuller Test for Stationarity
def dicky_fuller(TS):
    result = adfuller(TS)
    print('ADF Statistic: %f' % result[0])
    print('p-value: %f' % result[1])
    print('Critical Values:')
    for key, value in result[4].items():
        print('\t%s: %.3f' % (key, value))

# %%
# Dicky Fuller Test for Stationarity
dicky_fuller(y_train)
# Out:
# ADF Statistic: -3.998469
# p-value: 0.001419
# Critical Values:
# 	1%: -3.437
# 	5%: -2.865
# 	10%: -2.568

# %% [markdown]
# Our target data is stationary! Lets do a grid search for the optimal orders for our data.

# %%
#origionally all of the max elements were set to 5, but that took 2+ hours to run, so I lowered it to 3
def sarima_elements(TS):
    '''
This function will calculate the optimal elements to use in our model. The model we will be using following 
this function requires both the time series and the order of elements in order to create the model. 

An ARIMA model requires 3 elements - p, d, and q. This function will cycle through all numbers between 0-2 
to find the optimal values for these elements.

p - this is the order of the auto-regressive (AR) part of the ARIMA model. This states the lag we want to 
incorporate into our model, thereby enabling our model to take the past into consideration. 
d - integrated (I) part of the model, which states the order of 
how many times the model has been differenced to find optimal  stationarity.
q - this is the moving average (MA) order of the ARIMA model, which represents the error found in the model. 

The seasonal ARIMA contains these three elements along with a seasonal element, set here as 52, to represent 
the approximate number of weeks in a year.  
    '''
    auto = pm.auto_arima(TS, start_p=4, start_q=0, max_p=7,
                  max_q=3, max_d=3, start_P=0, start_Q=0, max_P=3,
                  max_Q=3, m=52, max_order=None, stepwise=True, 
                  trace=True, random_state = 42)
    return auto

# %%
# %%time
target_elements = sarima_elements(y_train)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(4,0,0)(0,0,0)[52] intercept   : AIC=10122.603, Time=0.64 sec
#  ARIMA(0,0,0)(0,0,0)[52] intercept   : AIC=14527.298, Time=0.02 sec
#  ARIMA(1,0,0)(1,0,0)[52] intercept   : AIC=inf, Time=6.52 sec
#  ARIMA(0,0,1)(0,0,1)[52] intercept   : AIC=13334.904, Time=13.44 sec
#  ARIMA(0,0,0)(0,0,0)[52]             : AIC=14966.882, Time=0.02 sec
#  ARIMA(4,0,0)(1,0,0)[52] intercept   : AIC=10124.349, Time=17.37 sec
#  ARIMA(4,0,0)(0,0,1)[52] intercept   : AIC=10124.339, Time=20.79 sec
#  ARIMA(4,0,0)(1,0,1)[52] intercept   : AIC=10126.055, Time=35.06 sec
#  ARIMA(3,0,0)(0,0,0)[52] intercept   : AIC=10204.404, Time=0.27 sec
#  ARIMA(5,0,0)(0,0,0)[52] intercept   : AIC=10103.957, Time=0.60 sec
#  ARIMA(5,0,0)(1,0,0)[52] intercept   : AIC=10105.803, Time=23.24 sec
#  ARIMA(5,0,0)(0,0,1)[52] intercept   : AIC=10105.797, Time=15.66 sec
#  ARIMA(5,0,0)(1,0,1)[52] intercept   : AIC=10107.800, Time=20.51 sec
#  ARIMA(6,0,0)(0,0,0)[52] intercept   : AIC=10076.242, Time=0.99 sec
#  ARIMA(6,0,0)(1,0,0)[52] intercept   : AIC=10078.205, Time=30.95 sec
#  ARIMA(6,0,0)(0,0,1)[52] intercept   : AIC=10078.207, Time=20.31 sec
#  ARIMA(6,0,0)(1,0,1)[52] intercept   : AIC=10080.204, Time=23.27 sec
#  ARIMA(7,0,0)(0,0,0)[52] intercept   : AIC=10070.811, Time=1.29 sec
#  ARIMA(7,0,0)(1,0,0)[52] intercept   : AIC=10072.783, Time=38.59 sec
#  ARIMA(7,0,0)(0,0,1)[52] intercept   : AIC=10072.784, Time=21.83 sec
#  ARIMA(7,0,0)(1,0,1)[52] intercept   : AIC=10074.782, Time=26.52 sec
#  ARIMA(7,0,1)(0,0,0)[52] intercept   : AIC=10033.341, Time=2.27 sec
#  ARIMA(7,0,1)(1,0,0)[52] intercept   : AIC=10035.382, Time=65.36 sec
#  ARIMA(7,0,1)(0,0,1)[52] intercept   : AIC=10035.557, Time=47.69 sec
#  ARIMA(7,0,1)(1,0,1)[52] intercept   : AIC=10037.284, Time=60.10 sec
#  ARIMA(6,0,1)(0,0,0)[52] intercept   : AIC=10076.773, Time=3.83 sec
#  ARIMA(7,0,2)(0,0,0)[52] intercept   : AIC=9945.269, Time=3.30 sec
#  ARIMA(7,0,2)(1,0,0)[52] intercept   : AIC=9947.394, Time=108.82 sec
#  ARIMA(7,0,2)(0,0,1)[52] intercept   : AIC=9947.286, Time=76.05 sec
#  ARIMA(7,0,2)(1,0,1)[52] intercept   : AIC=9945.762, Time=92.54 sec
#  ARIMA(6,0,2)(0,0,0)[52] intercept   : AIC=10004.367, Time=3.06 sec
#  ARIMA(7,0,3)(0,0,0)[52] intercept   : AIC=9938.375, Time=2.33 sec
#  ARIMA(7,0,3)(1,0,0)[52] intercept   : AIC=9940.711, Time=57.96 sec
#  ARIMA(7,0,3)(0,0,1)[52] intercept   : AIC=9940.547, Time=39.65 sec
#  ARIMA(7,0,3)(1,0,1)[52] intercept   : AIC=inf, Time=68.84 sec
#  ARIMA(6,0,3)(0,0,0)[52] intercept   : AIC=9975.501, Time=2.74 sec
#  ARIMA(7,0,3)(0,0,0)[52]             : AIC=9943.359, Time=1.67 sec
#
# Best model:  ARIMA(7,0,3)(0,0,0)[52] intercept
# Total fit time: 954.238 seconds
# CPU times: user 21min 51s, sys: 3min 36s, total: 25min 27s
# Wall time: 15min 55s

# %%
# get the plots and summary about our model
target_elements.plot_diagnostics(figsize=(12,8))
target_elements.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  951
# Model:               SARIMAX(7, 0, 3)   Log Likelihood               -4957.187
# Date:                Wed, 26 Apr 2023   AIC                           9938.375
# Time:                        09:22:34   BIC                           9996.665
# Sample:                             0   HQIC                          9960.583
#                                 - 951
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      6.4508      8.706      0.741      0.459     -10.613      23.515
# ar.L1          0.1878      0.032      5.949      0.000       0.126       0.250
# ar.L2          0.2754      0.028      9.826      0.000       0.220       0.330
# ar.L3          0.6949      0.021     32.489      0.000       0.653       0.737
# ar.L4          0.2895      0.031      9.193      0.000       0.228       0.351
# ar.L5          0.0661      0.013      5.123      0.000       0.041       0.091
# ar.L6         -0.1116      0.012     -9.040      0.000      -0.136      -0.087
# ar.L7         -0.4394      0.010    -43.800      0.000      -0.459      -0.420
# ma.L1          0.8536      0.038     22.319      0.000       0.779       0.929
# ma.L2          0.8299      0.028     29.918      0.000       0.776       0.884
# ma.L3          0.2292      0.033      7.013      0.000       0.165       0.293
# sigma2      1928.7277     29.977     64.340      0.000    1869.973    1987.482
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.09   Jarque-Bera (JB):             56578.89
# Prob(Q):                              0.77   Prob(JB):                         0.00
# Heteroskedasticity (H):              11.87   Skew:                            -0.86
# Prob(H) (two-sided):                  0.00   Kurtosis:                        40.75
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
#getting the last date we want to predict until
last_date_test = y_test.last_valid_index()
first_date_test = y_test.first_valid_index()
print(f"{first_date_test},{last_date_test}")
# Out:
# 2022-10-15 00:00:00,2022-11-03 00:00:00

# %%
# creating our baseline ARIMA model for our target data
ARIMA_MODEL = sm.tsa.statespace.SARIMAX((y_train), order=target_elements.order, 
                                        seasonal_order=target_elements.seasonal_order,enforce_stationarity=False, 
                                        enforce_invertibility=False)

# Fit the model and return the results
output = ARIMA_MODEL.fit()

# forcast 
output_forcast = output.forecast(steps= last_date_test)
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           11     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.15531D+00    |proj g|=  2.52093D-01
#
# At iterate    5    f=  5.68166D+00    |proj g|=  4.31861D-01
#  This problem is unconstrained.
# At iterate   10    f=  5.26205D+00    |proj g|=  2.47039D-01
#
# At iterate   15    f=  5.19858D+00    |proj g|=  1.45736D-01
#
# At iterate   20    f=  5.18693D+00    |proj g|=  6.39196D-02
#
# At iterate   25    f=  5.18544D+00    |proj g|=  7.04381D-02
#
# At iterate   30    f=  5.18216D+00    |proj g|=  2.04584D-02
#
# At iterate   35    f=  5.18037D+00    |proj g|=  3.33609D-02
#
# At iterate   40    f=  5.17886D+00    |proj g|=  1.70512D-02
#
# At iterate   45    f=  5.17858D+00    |proj g|=  3.48971D-03
#
# At iterate   50    f=  5.17857D+00    |proj g|=  1.34387D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    11     50     60      1     0     0   1.344D-03   5.179D+00
#   F =   5.1785734045063032
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# /Users/rachelsanderlin/opt/anaconda3/envs/covid-env/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
# get the confidence interval for our model
output_conf= output.get_forecast(steps= last_date_test).conf_int()

# %%
def plot_model(y_train, y_test, predicted_forcast, title, y_lable, conf_interval =None, cutoff_date=None):
    # plotting the prediction
    fig, ax = plt.subplots(figsize=(12, 8))
# took only a potion of the data to better show how the predicted data preformed 
    ax.plot(y_train[cutoff_date :], label='Training Data')
    ax.plot(y_test, label='Testing Data')
    predicted_forcast.plot(ax=ax, label='Forecasted Data')
    ax.fill_between(conf_interval.index,
                        conf_interval.iloc[:, 0],
                        conf_interval.iloc[:, 1], color='k', alpha=0.25)
    ax.set_title(title, fontsize=30)
    ax.set_xlabel('Dates')
    ax.set_ylabel(y_lable)
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5));

# %%
plot_model(y_train, y_test, output_forcast, "7-Day Average COVID-19 Cases Forcast",
          '7-Day Average COVID-19 Cases', conf_interval =output_conf, cutoff_date = '2022-09-01' )

# %%
# plotting the prediction
fig, ax = plt.subplots(figsize=(12, 8))
# took only a potion of the data to better show how the predicted data preformed 
ax.plot(y_train['2022-09-01' :], label='Training Data')
ax.plot(y_test, label='Testing Data')
output_forcast.plot(ax=ax, label='Forecasted Value')
ax.fill_between(output_conf.index,
                    output_conf.iloc[:, 0],
                    output_conf.iloc[:, 1], color='k', alpha=0.25)
ax.set_title("7-Day Average COVID-19 Cases Forcast", fontsize=30)
ax.set_xlabel('Dates')
ax.set_ylabel('7-Day Average COVID-19 Cases')
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5));

# %% [markdown]
# Okay, lets talk about this graph. Initially when I modeled this data I saw that the model was predicting a straight line. This led me to assume that something was wrong with my model. I tried re-running the parameters, subtracting the moving average from the target variable, using just the moving average to model the data, taking the log of the target data- none of them really improved upon the model. I then tried running the data through Facebook Prophet in a different notebook (see [here](https://github.com/sanderlin2013/Predicting-COVID-19-in-PA/blob/main/alt-notebook_prophet.ipynb) and tried modeling the data pre and post the Omicron spike seen around January 2022 in another notebook (see [here](https://github.com/sanderlin2013/Predicting-COVID-19-in-PA/blob/main/alt_notebook_remove_omicron.ipynb) - I ended up using the log versions of the data to make both models more stationary for modeling).
#
# At the end of the day, none of these methods made a difference - the best mode was using the 7 day average case counts, and the predictions more or less trended towards a straight line during their prediction. This apparently is not a unique occurrence in univariate SARIMA models - in the official [documentation on forecasting in statsmodels](https://www.statsmodels.org/dev/examples/notebooks/generated/statespace_forecasting.html#Prediction-vs-Forecasting) it states, specifically about a straight line SARIMAX forcast: "The forecast above may not look very impressive, as it is almost a **straight line**. This is because this is a very simple, univariate forecasting model. Nonetheless, *keep in mind that these simple forecasting models can be extremely competitive*."
#
# For more information on this phenomenon, feel free to read more [here](https://github.com/statsmodels/statsmodels/issues/3852).
#
# I finally realized that what was most affecting my predictions was that I was predicting too far into the future. By reducing my test data from 20% of my dataset (almost 100 days) to 20, my model performance vastly improved.
#
# Lets look at some loss functions to asses how well the model preformed.

# %%
# https://stackoverflow.com/questions/3308102/how-to-extract-the-n-th-elements-from-a-list-of-tuples
forcast_date_list = list(output_forcast.items())
n=1
forcast_list = [x[n] for x in forcast_date_list]
#forcast_list

# %%
print('MAE:', np.mean(abs(forcast_list  - y_test.values)))
print('RMSE:', np.sqrt(np.mean((forcast_list  - y_test.values)**2)))
print('MAPE:', np.mean(abs((forcast_list  - y_test.values)/y_test.values)))
# Out:
# MAE: 22.082660363074023
# RMSE: 28.91175740690455
# MAPE: 0.12197275172442486

# %% [markdown]
# Based on these error terms and looking at the plot of our model, we can see that our model isn't perfect, and like most time series preforms worse (the confidence interval widens) the farther out we try to predict the data.
#
# Lets see if we can improve on these predictions by using a **multivariate time series model**.

# %% [markdown]
# # Multivariate Time Series Model
#
# ## PCA
#
# The first step to trying out multivariate models is figuring out what variables we would like to include in our model! We have over 400 symptoms to consider from the Google dataset - using all of them is would be too computationally expensive. Luckily, we can use Principal Component Analysis (PCA) for dimensionality reduction!
#
# PCA involves transforming a large set of variables into a smaller set of uncorrelated variables while keeping most of the information in the original data. PCA works by identifying the principal components (PCs) of the data, which are linear combinations of the original variables that explain the most variance in the data. The first PC explains the most variance, followed by the second PC, and so on. By selecting only the top few PCs, we can reduce the dimensionality of the data while retaining most of the important information.

# %%
# Perform PCA on training data
pca = PCA(n_components=15).fit(X_train)
#plot scree plot
PC_values = np.arange(pca.n_components_) + 1
plt.plot(PC_values, pca.explained_variance_ratio_, 'o-', linewidth=2, color='blue')
plt.title('Scree Plot')
plt.xlabel('Principal Component')
plt.ylabel('Variance Explained')
plt.show()

# %%
# restructuring our `y_train` data so we can add it to our VAR model later
df_y_train= pd.DataFrame(y_train)
df_y_train= df_y_train.reset_index(names = ['date'])
df_y_train
# Out:
#           date  Target
# 0   2020-03-08     0.1
# 1   2020-03-09     0.1
# 2   2020-03-10     0.4
# 3   2020-03-11     0.9
# 4   2020-03-12     1.1
# ..         ...     ...
# 946 2022-10-10   166.0
# 947 2022-10-11   185.1
# 948 2022-10-12   210.3
# 949 2022-10-13   193.7
# 950 2022-10-14   197.3
#
# [951 rows x 2 columns]

# %% [markdown]
# So the k number of components I'm going to choose will be 8, based on where the scree plot drops off.

# %%
#instantiating the PCA
pca = PCA(n_components=2)
# fitting and transforming the PCA on our training data
principalComponents = pca.fit_transform(X_train)
#dataframe with PC's
df_pca = pd.DataFrame(principalComponents, columns = ['PC1', 'PC2'])

#creating on dataframe, with the dates as an index
principalComponents = pd.concat([df_y_train, df_pca], axis = 1)
principalComponents.set_index('date', inplace=True)

# %%
principalComponents
# Out:
#             Target        PC1       PC2
# date
# 2020-03-08     0.1  23.191009 -0.482271
# 2020-03-09     0.1  40.048743  0.523454
# 2020-03-10     0.4  50.739527  0.553614
# 2020-03-11     0.9  72.862522  0.596096
# 2020-03-12     1.1  90.560429  0.228386
# ...            ...        ...       ...
# 2022-10-10   166.0   2.734843  0.287215
# 2022-10-11   185.1   3.182493  0.583910
# 2022-10-12   210.3   2.429584  0.524616
# 2022-10-13   193.7   1.839219  0.459620
# 2022-10-14   197.3   0.450123 -0.030646
#
# [951 rows x 3 columns]

# %%
#modeling the PC's and target data
fig, axes = plt.subplots(nrows=3, ncols= 1, figsize=(10,6))
for i, ax in enumerate(axes.flatten()):
    data = principalComponents[principalComponents.columns[i]]
    ax.plot(data, linewidth=1)
    ax.set_title(principalComponents.columns[i])
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize=6)

plt.tight_layout();

# %%
# explained variance for each PC
print(pca.explained_variance_ratio_)
# Out:
# [0.60491904 0.13039893]

# %% [markdown]
# Looking at the explain variances, it may only be worth looking into the first three PC's for our final model, as the rest contain less than 5% of the explained variance. Let's see if these variables are stationary by looking at their Dicky-Fuller scores.

# %%
for col in principalComponents:
    print(col)
    dicky_fuller(principalComponents[col])
# Out:
# Target
# ADF Statistic: -3.998469
# p-value: 0.001419
# Critical Values:
# 	1%: -3.437
# 	5%: -2.865
# 	10%: -2.568
# PC1
# ADF Statistic: -6.278851
# p-value: 0.000000
# Critical Values:
# 	1%: -3.437
# 	5%: -2.865
# 	10%: -2.568
# PC2
# ADF Statistic: -17.966173
# p-value: 0.000000
# Critical Values:
# 	1%: -3.437
# 	5%: -2.865
# 	10%: -2.568

# %% [markdown]
# Out of the first three PC's, only the first two are stationary. Let's further explore those two variables against our target variable using a granger causality test.

# %% [markdown]
# ### Granger Causality Test
#
# What is a granger causality test? Granger causality is a statistical test that helps determine whether one time series can be used to predict another time series. The test is based on the idea that if a time series X "Granger-causes" another time series Y, then information about the past values of X should help predict the future values of Y better than just using information about the past values of Y alone. In other words, if changes in X can be used to predict changes in Y better than simply looking at past values of Y, then X is said to Granger-cause Y.
#
# Here we are going to look at the Granger-cause between our target variable, and PC1 and PC2. When looking at these Granger-causes, it's most important to look at the p-values.

# %%
print('7-day Average New Cases causes PC1\n')
print('------------------')
granger_1 = grangercausalitytests(principalComponents[['PC1', 'Target']], 10)

print('\nPC1 causes 7-day Average New Cases\n')
print('------------------')
granger_2 = grangercausalitytests(principalComponents[['Target', 'PC1']], 10)
# Out:
# 7-day Average New Cases causes PC1
#
# ------------------
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.4995  , p=0.2211  , df_denom=947, df_num=1
# ssr based chi2 test:   chi2=1.5043  , p=0.2200  , df=1
# likelihood ratio test: chi2=1.5031  , p=0.2202  , df=1
# parameter F test:         F=1.4995  , p=0.2211  , df_denom=947, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.2077  , p=0.8125  , df_denom=944, df_num=2
# ssr based chi2 test:   chi2=0.4175  , p=0.8116  , df=2
# likelihood ratio test: chi2=0.4175  , p=0.8116  , df=2
# parameter F test:         F=0.2077  , p=0.8125  , df_denom=944, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.4985  , p=0.6834  , df_denom=941, df_num=3
# ssr based chi2 test:   chi2=1.5065  , p=0.6808  , df=3
# likelihood ratio test: chi2=1.5053  , p=0.6810  , df=3
# parameter F test:         F=0.4985  , p=0.6834  , df_denom=941, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.5776  , p=0.6790  , df_denom=938, df_num=4
# ssr based chi2 test:   chi2=2.3325  , p=0.6749  , df=4
# likelihood ratio test: chi2=2.3296  , p=0.6754  , df=4
# parameter F test:         F=0.5776  , p=0.6790  , df_denom=938, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.9048  , p=0.0910  , df_denom=935, df_num=5
# ssr based chi2 test:   chi2=9.6362  , p=0.0862  , df=5
# likelihood ratio test: chi2=9.5874  , p=0.0878  , df=5
# parameter F test:         F=1.9048  , p=0.0910  , df_denom=935, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.2393  , p=0.2836  , df_denom=932, df_num=6
# ssr based chi2 test:   chi2=7.5396  , p=0.2738  , df=6
# likelihood ratio test: chi2=7.5097  , p=0.2763  , df=6
# parameter F test:         F=1.2393  , p=0.2836  , df_denom=932, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.6101  , p=0.1288  , df_denom=929, df_num=7
# ssr based chi2 test:   chi2=11.4526 , p=0.1201  , df=7
# likelihood ratio test: chi2=11.3837 , p=0.1227  , df=7
# parameter F test:         F=1.6101  , p=0.1288  , df_denom=929, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=2.3742  , p=0.0156  , df_denom=926, df_num=8
# ssr based chi2 test:   chi2=19.3420 , p=0.0131  , df=8
# likelihood ratio test: chi2=19.1463 , p=0.0141  , df=8
# parameter F test:         F=2.3742  , p=0.0156  , df_denom=926, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=4.2288  , p=0.0000  , df_denom=923, df_num=9
# ssr based chi2 test:   chi2=38.8426 , p=0.0000  , df=9
# likelihood ratio test: chi2=38.0631 , p=0.0000  , df=9
# parameter F test:         F=4.2288  , p=0.0000  , df_denom=923, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=3.0599  , p=0.0008  , df_denom=920, df_num=10
# ssr based chi2 test:   chi2=31.2978 , p=0.0005  , df=10
# likelihood ratio test: chi2=30.7886 , p=0.0006  , df=10
# parameter F test:         F=3.0599  , p=0.0008  , df_denom=920, df_num=10
#
# PC1 causes 7-day Average New Cases
#
# ------------------
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=11.4745 , p=0.0007  , df_denom=947, df_num=1
# ssr based chi2 test:   chi2=11.5108 , p=0.0007  , df=1
# likelihood ratio test: chi2=11.4416 , p=0.0007  , df=1
# parameter F test:         F=11.4745 , p=0.0007  , df_denom=947, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.4281  , p=0.0329  , df_denom=944, df_num=2
# ssr based chi2 test:   chi2=6.8926  , p=0.0319  , df=2
# likelihood ratio test: chi2=6.8677  , p=0.0323  , df=2
# parameter F test:         F=3.4281  , p=0.0329  , df_denom=944, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.3657  , p=0.2519  , df_denom=941, df_num=3
# ssr based chi2 test:   chi2=4.1275  , p=0.2480  , df=3
# likelihood ratio test: chi2=4.1185  , p=0.2489  , df=3
# parameter F test:         F=1.3657  , p=0.2519  , df_denom=941, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.0046  , p=0.4041  , df_denom=938, df_num=4
# ssr based chi2 test:   chi2=4.0569  , p=0.3984  , df=4
# likelihood ratio test: chi2=4.0483  , p=0.3995  , df=4
# parameter F test:         F=1.0046  , p=0.4041  , df_denom=938, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.1231  , p=0.3463  , df_denom=935, df_num=5
# ssr based chi2 test:   chi2=5.6817  , p=0.3384  , df=5
# likelihood ratio test: chi2=5.6647  , p=0.3402  , df=5
# parameter F test:         F=1.1231  , p=0.3463  , df_denom=935, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.8465  , p=0.0872  , df_denom=932, df_num=6
# ssr based chi2 test:   chi2=11.2335 , p=0.0814  , df=6
# likelihood ratio test: chi2=11.1673 , p=0.0833  , df=6
# parameter F test:         F=1.8465  , p=0.0872  , df_denom=932, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=2.2580  , p=0.0278  , df_denom=929, df_num=7
# ssr based chi2 test:   chi2=16.0615 , p=0.0246  , df=7
# likelihood ratio test: chi2=15.9264 , p=0.0258  , df=7
# parameter F test:         F=2.2580  , p=0.0278  , df_denom=929, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=2.4488  , p=0.0126  , df_denom=926, df_num=8
# ssr based chi2 test:   chi2=19.9501 , p=0.0105  , df=8
# likelihood ratio test: chi2=19.7420 , p=0.0114  , df=8
# parameter F test:         F=2.4488  , p=0.0126  , df_denom=926, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=3.2982  , p=0.0006  , df_denom=923, df_num=9
# ssr based chi2 test:   chi2=30.2945 , p=0.0004  , df=9
# likelihood ratio test: chi2=29.8176 , p=0.0005  , df=9
# parameter F test:         F=3.2982  , p=0.0006  , df_denom=923, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=3.8853  , p=0.0000  , df_denom=920, df_num=10
# ssr based chi2 test:   chi2=39.7396 , p=0.0000  , df=10
# likelihood ratio test: chi2=38.9234 , p=0.0000  , df=10
# parameter F test:         F=3.8853  , p=0.0000  , df_denom=920, df_num=10

# %% [markdown]
# Here we see that while there are only a few viable lags when examining if our target variable Granger-causes PC1 (lags 8, 9, and 10), there are more lags that express that PC1 Granger-causes our target variable (lags 8, 9, and 10 as well as 7, 2, and 1).
#
# In short, we may be able to use the lags of the other variable to better model our predictions then if we modeled the variables separately. Because we have more lags that express that PC1 Granger-causes our target variable, that seems to indicate a higher likelihood that the causality is more weighed in that direction.
#
# **REWRITE ENDING**

# %% [markdown]
# ## VAR model

# %%
# creating a dataframe with the variables we want in our VAR model
var_df = principalComponents[['Target','PC1', 'PC2']]
var_df
# Out:
#             Target        PC1       PC2
# date
# 2020-03-08     0.1  23.191009 -0.482271
# 2020-03-09     0.1  40.048743  0.523454
# 2020-03-10     0.4  50.739527  0.553614
# 2020-03-11     0.9  72.862522  0.596096
# 2020-03-12     1.1  90.560429  0.228386
# ...            ...        ...       ...
# 2022-10-10   166.0   2.734843  0.287215
# 2022-10-11   185.1   3.182493  0.583910
# 2022-10-12   210.3   2.429584  0.524616
# 2022-10-13   193.7   1.839219  0.459620
# 2022-10-14   197.3   0.450123 -0.030646
#
# [951 rows x 3 columns]

# %%
#instantiating the model
var_model = VAR(var_df)
# Out:
# /Users/rachelsanderlin/opt/anaconda3/envs/covid-env/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)

# %%
# code inspiration taken from https://github.com/nachi-hebbar/Multivariate-Time-Series-Forecasting

#finding the best order for our VAR model
sorted_order=var_model.select_order(maxlags=20)
print(sorted_order.summary())
# Out:
#  VAR Order Selection (* highlights the minimums)
# ==================================================
#        AIC         BIC         FPE         HQIC
# --------------------------------------------------
# 0        17.77       17.79   5.221e+07       17.78
# 1        11.05       11.11   6.272e+04       11.07
# 2        10.95       11.06   5.722e+04       11.00
# 3        10.81       10.96   4.932e+04       10.87
# 4        10.69       10.89   4.381e+04       10.76
# 5        10.59       10.84   3.993e+04       10.69
# 6        10.42       10.71   3.337e+04       10.53
# 7        10.40       10.74   3.290e+04       10.53
# 8        10.14      10.53*   2.535e+04      10.29*
# 9        10.14       10.58   2.538e+04       10.31
# 10       10.13       10.62   2.518e+04       10.32
# 11       10.15       10.68   2.555e+04       10.35
# 12       10.14       10.72   2.535e+04       10.36
# 13       10.14       10.77   2.542e+04       10.38
# 14       10.16       10.83   2.582e+04       10.41
# 15      10.03*       10.75  2.281e+04*       10.31
# 16       10.04       10.80   2.287e+04       10.33
# 17       10.04       10.85   2.298e+04       10.35
# 18       10.04       10.90   2.304e+04       10.37
# 19       10.06       10.96   2.329e+04       10.40
# 20       10.05       11.00   2.306e+04       10.41
# --------------------------------------------------

# %%
#fitting our VAR model
var_model = VARMAX(var_df, order=(8,0), enforce_stationarity= True)
fitted_model = var_model.fit(disp=False)
print(fitted_model.summary())
# Out:
# /Users/rachelsanderlin/opt/anaconda3/envs/covid-env/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /Users/rachelsanderlin/opt/anaconda3/envs/covid-env/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#                               Statespace Model Results
# ====================================================================================
# Dep. Variable:     ['Target', 'PC1', 'PC2']   No. Observations:                  951
# Model:                               VAR(8)   Log Likelihood               -9424.302
#                                 + intercept   AIC                          19010.604
# Date:                      Wed, 26 Apr 2023   BIC                          19404.062
# Time:                              09:23:27   HQIC                         19160.509
# Sample:                          03-08-2020
#                                - 10-14-2022
# Covariance Type:                        opg
# ================================================================================================
# Ljung-Box (L1) (Q):       0.02, 0.59, 0.13   Jarque-Bera (JB):   56756.25, 92779.41, 32117597.78
# Prob(Q):                  0.88, 0.44, 0.72   Prob(JB):                          0.00, 0.00, 0.00
# Heteroskedasticity (H): 10.20, 0.20, 48.69   Skew:                            -0.43, 1.21, 29.61
# Prob(H) (two-sided):      0.00, 0.00, 0.00   Kurtosis:                      40.84, 51.33, 901.35
#                          Results for equation Target
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      4.9281      4.274      1.153      0.249      -3.449      13.305
# L1.Target      1.0256      0.017     62.081      0.000       0.993       1.058
# L1.PC1         0.4654      3.280      0.142      0.887      -5.962       6.893
# L1.PC2         0.0719     10.168      0.007      0.994     -19.857      20.001
# L2.Target      0.2085      0.028      7.414      0.000       0.153       0.264
# L2.PC1         1.0068      4.007      0.251      0.802      -6.846       8.860
# L2.PC2        -0.0614     10.009     -0.006      0.995     -19.679      19.556
# L3.Target      0.0137      0.038      0.362      0.717      -0.061       0.088
# L3.PC1        -1.7419      3.985     -0.437      0.662      -9.552       6.068
# L3.PC2        -0.1429      9.976     -0.014      0.989     -19.695      19.410
# L4.Target     -0.0636      0.029     -2.193      0.028      -0.121      -0.007
# L4.PC1         1.9609      2.777      0.706      0.480      -3.481       7.403
# L4.PC2         0.0169      9.336      0.002      0.999     -18.281      18.315
# L5.Target      0.0385      0.035      1.098      0.272      -0.030       0.107
# L5.PC1        -2.3645      3.695     -0.640      0.522      -9.606       4.877
# L5.PC2        -0.1255     13.795     -0.009      0.993     -27.163      26.912
# L6.Target     -0.1597      0.034     -4.657      0.000      -0.227      -0.093
# L6.PC1         1.6439      3.380      0.486      0.627      -4.982       8.269
# L6.PC2        -0.0234     13.151     -0.002      0.999     -25.800      25.753
# L7.Target     -0.4427      0.033    -13.235      0.000      -0.508      -0.377
# L7.PC1        -1.2582      3.419     -0.368      0.713      -7.960       5.444
# L7.PC2        -0.0262      9.520     -0.003      0.998     -18.684      18.632
# L8.Target      0.3668      0.018     20.246      0.000       0.331       0.402
# L8.PC1         0.5326      2.094      0.254      0.799      -3.572       4.637
# L8.PC2        -0.2344      6.678     -0.035      0.972     -13.323      12.854
#                            Results for equation PC1
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0284      0.160      0.177      0.859      -0.285       0.342
# L1.Target     -0.0016      0.003     -0.542      0.588      -0.007       0.004
# L1.PC1         1.2951      0.063     20.465      0.000       1.171       1.419
# L1.PC2     -6.821e-05      0.311     -0.000      1.000      -0.610       0.610
# L2.Target      0.0015      0.004      0.379      0.705      -0.006       0.009
# L2.PC1        -0.5652      0.069     -8.196      0.000      -0.700      -0.430
# L2.PC2        -0.0188      0.300     -0.063      0.950      -0.607       0.569
# L3.Target     -0.0002      0.004     -0.068      0.946      -0.007       0.007
# L3.PC1         0.2557      0.083      3.091      0.002       0.094       0.418
# L3.PC2         0.0068      0.290      0.023      0.981      -0.562       0.575
# L4.Target      0.0028      0.003      0.906      0.365      -0.003       0.009
# L4.PC1        -0.0110      0.099     -0.111      0.912      -0.205       0.183
# L4.PC2         0.0113      0.154      0.074      0.941      -0.290       0.313
# L5.Target     -0.0017      0.004     -0.430      0.667      -0.009       0.006
# L5.PC1        -0.0577      0.055     -1.041      0.298      -0.166       0.051
# L5.PC2         0.0282      0.109      0.258      0.796      -0.186       0.242
# L6.Target      0.0001      0.004      0.030      0.976      -0.008       0.008
# L6.PC1         0.0594      0.052      1.143      0.253      -0.042       0.161
# L6.PC2         0.0534      0.114      0.470      0.639      -0.169       0.276
# L7.Target     -0.0002      0.003     -0.060      0.952      -0.006       0.006
# L7.PC1         0.3928      0.073      5.405      0.000       0.250       0.535
# L7.PC2         0.0215      0.130      0.166      0.869      -0.233       0.276
# L8.Target     -0.0009      0.002     -0.389      0.697      -0.006       0.004
# L8.PC1        -0.4238      0.038    -11.207      0.000      -0.498      -0.350
# L8.PC2        -0.0141      0.143     -0.099      0.921      -0.294       0.266
#                            Results for equation PC2
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.1365      1.731      0.079      0.937      -3.256       3.529
# L1.Target      0.0006      0.030      0.020      0.984      -0.058       0.059
# L1.PC1         0.2043      0.838      0.244      0.807      -1.438       1.846
# L1.PC2         0.2291      0.434      0.528      0.598      -0.622       1.080
# L2.Target     -0.0003      0.045     -0.007      0.995      -0.089       0.088
# L2.PC1        -0.1699      0.944     -0.180      0.857      -2.019       1.679
# L2.PC2         0.0600      0.490      0.122      0.903      -0.900       1.020
# L3.Target      0.0003      0.039      0.008      0.994      -0.075       0.076
# L3.PC1        -0.0433      0.774     -0.056      0.955      -1.561       1.475
# L3.PC2         0.0316      0.205      0.154      0.877      -0.370       0.433
# L4.Target     -0.0002      0.046     -0.004      0.997      -0.091       0.090
# L4.PC1        -0.0046      0.986     -0.005      0.996      -1.937       1.928
# L4.PC2         0.0017      2.363      0.001      0.999      -4.630       4.633
# L5.Target     -0.0005      0.047     -0.011      0.992      -0.093       0.092
# L5.PC1        -0.0914      1.157     -0.079      0.937      -2.358       2.176
# L5.PC2         0.0065      4.192      0.002      0.999      -8.210       8.223
# L6.Target     -0.0004      0.062     -0.006      0.995      -0.122       0.121
# L6.PC1         0.0716      1.274      0.056      0.955      -2.426       2.569
# L6.PC2         0.0148      5.232      0.003      0.998     -10.240      10.270
# L7.Target     -0.0001      0.062     -0.002      0.998      -0.122       0.122
# L7.PC1         0.0916      1.035      0.088      0.930      -1.937       2.120
# L7.PC2         0.0147      3.822      0.004      0.997      -7.477       7.507
# L8.Target      0.0004      0.041      0.009      0.993      -0.080       0.081
# L8.PC1        -0.0763      0.558     -0.137      0.891      -1.169       1.017
# L8.PC2         0.0151      1.311      0.012      0.991      -2.555       2.586
#                                 Error covariance matrix
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# sqrt.var.Target        44.5983      1.069     41.710      0.000      42.503      46.694
# sqrt.cov.Target.PC1     0.0445      0.138      0.323      0.746      -0.225       0.315
# sqrt.var.PC1            1.6873      0.046     36.573      0.000       1.597       1.778
# sqrt.cov.Target.PC2    -0.0661      3.013     -0.022      0.983      -5.972       5.840
# sqrt.cov.PC1.PC2        0.2087      2.350      0.089      0.929      -4.397       4.815
# sqrt.var.PC2            3.7972      0.093     40.795      0.000       3.615       3.980
# =======================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
#getting predictions based on the VAR model
predict = fitted_model.get_prediction(start=first_date_test, end=last_date_test)
predictions=predict.predicted_mean

#get confidence interval
var_conf = fitted_model.conf_int(alpha=0.05)

# %%
#
predictions.columns=['Target predicted','PC1 predicted','PC2 predicted', ]
predictions
# Out:
#             Target predicted  PC1 predicted  PC2 predicted
# 2022-10-15        197.974027      -0.561133      -0.600549
# 2022-10-16        203.824776      -0.105458      -0.348377
# 2022-10-17        216.832803       1.659667       0.330909
# 2022-10-18        212.397267       2.257765       0.621196
# 2022-10-19        211.945287       1.678268       0.527402
# 2022-10-20        224.988896       1.044748       0.244614
# 2022-10-21        230.017846       0.303346      -0.097328
# 2022-10-22        237.116887      -0.326341      -0.347270
# 2022-10-23        240.483013      -0.139938      -0.205655
# 2022-10-24        241.608309       0.899915       0.222306
# 2022-10-25        251.521837       1.435681       0.480060
# 2022-10-26        259.649468       1.082361       0.412989
# 2022-10-27        263.060392       0.542659       0.190347
# 2022-10-28        269.512346       0.083202      -0.025384
# 2022-10-29        273.725040      -0.246102      -0.163170
# 2022-10-30        279.787001      -0.136152      -0.085008
# 2022-10-31        286.188164       0.469466       0.178712
# 2022-11-01        289.114740       0.885794       0.358527
# 2022-11-02        293.860330       0.708427       0.324201
# 2022-11-03        299.648376       0.304620       0.169215

# %%
plot_model(y_train, y_test, output_forcast, "7-Day Average COVID-19 Cases Forcast",
          '7-Day Average COVID-19 Cases', conf_interval =output_conf, cutoff_date = '2022-09-01' )

# %%
predictions["Target predicted"]
# Out:
# 2022-10-15    197.974027
# 2022-10-16    203.824776
# 2022-10-17    216.832803
# 2022-10-18    212.397267
# 2022-10-19    211.945287
# 2022-10-20    224.988896
# 2022-10-21    230.017846
# 2022-10-22    237.116887
# 2022-10-23    240.483013
# 2022-10-24    241.608309
# 2022-10-25    251.521837
# 2022-10-26    259.649468
# 2022-10-27    263.060392
# 2022-10-28    269.512346
# 2022-10-29    273.725040
# 2022-10-30    279.787001
# 2022-10-31    286.188164
# 2022-11-01    289.114740
# 2022-11-02    293.860330
# 2022-11-03    299.648376
# Freq: D, Name: Target predicted, dtype: float64

# %%
plot_model(var_df["Target"], y_test, predictions["Target predicted"], "VAR Model COVID-19 Cases Forcast",
          '7-Day Average COVID-19 Cases',conf_interval =var_conf, cutoff_date = '2022-09-01' )
# Out:
# /Users/rachelsanderlin/opt/anaconda3/envs/covid-env/lib/python3.9/site-packages/matplotlib/axis.py:1732: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   ret = self.converter.convert(x, self.units, self)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/opt/anaconda3/envs/covid-env/lib/python3.9/site-packages/matplotlib/axis.py:1732, in Axis.convert_units(self, x)
#    1731 try:
# -> 1732     ret = self.converter.convert(x, self.units, self)
#    1733 except Exception as e:
#
# File ~/opt/anaconda3/envs/covid-env/lib/python3.9/site-packages/pandas/plotting/_matplotlib/converter.py:285, in DatetimeConverter.convert(values, unit, axis)
#     284 else:
# --> 285     values = DatetimeConverter._convert_1d(values, unit, axis)
#     286 return values
#
# File ~/opt/anaconda3/envs/covid-env/lib/python3.9/site-packages/pandas/plotting/_matplotlib/converter.py:320, in DatetimeConverter._convert_1d(values, unit, axis)
#     318         pass
# --> 320     values = mdates.date2num(values)
#     322 return values
#
# File ~/opt/anaconda3/envs/covid-env/lib/python3.9/site-packages/matplotlib/dates.py:462, in date2num(d)
#     461         d = np.asarray(d)
# --> 462     d = d.astype('datetime64[us]')
#     464 d = np.ma.masked_array(d, mask=mask) if masked else d
#
# ValueError: Error parsing datetime string "intercept.Target" at position 0
#
# The above exception was the direct cause of the following exception:
#
# ConversionError                           Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 plot_model(var_df["Target"], y_test, predictions["Target predicted"], "VAR Model COVID-19 Cases Forcast",
#       2           '7-Day Average COVID-19 Cases',conf_interval =var_conf, cutoff_date = '2022-09-01' )
#
# Cell In[42], line 8, in plot_model(y_train, y_test, predicted_forcast, title, y_lable, conf_interval, cutoff_date)
#       6 ax.plot(y_test, label='Testing Data')
#       7 predicted_forcast.plot(ax=ax, label='Forecasted Data')
# ----> 8 ax.fill_between(conf_interval.index,
#       9                     conf_interval.iloc[:, 0],
#      10                     conf_interval.iloc[:, 1], color='k', alpha=0.25)
#      11 ax.set_title(title, fontsize=30)
#      12 ax.set_xlabel('Dates')
#
# File ~/opt/anaconda3/envs/covid-env/lib/python3.9/site-packages/matplotlib/__init__.py:1442, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1439 @functools.wraps(func)
#    1440 def inner(ax, *args, data=None, **kwargs):
#    1441     if data is None:
# -> 1442         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1444     bound = new_sig.bind(ax, *args, **kwargs)
#    1445     auto_label = (bound.arguments.get(label_namer)
#    1446                   or bound.kwargs.get(label_namer))
#
# File ~/opt/anaconda3/envs/covid-env/lib/python3.9/site-packages/matplotlib/axes/_axes.py:5431, in Axes.fill_between(self, x, y1, y2, where, interpolate, step, **kwargs)
#    5429 def fill_between(self, x, y1, y2=0, where=None, interpolate=False,
#    5430                  step=None, **kwargs):
# -> 5431     return self._fill_between_x_or_y(
#    5432         "x", x, y1, y2,
#    5433         where=where, interpolate=interpolate, step=step, **kwargs)
#
# File ~/opt/anaconda3/envs/covid-env/lib/python3.9/site-packages/matplotlib/axes/_axes.py:5337, in Axes._fill_between_x_or_y(self, ind_dir, ind, dep1, dep2, where, interpolate, step, **kwargs)
#    5332         kwargs["facecolor"] = \
#    5333             self._get_patches_for_fill.get_next_color()
#    5335 # Handle united data, such as dates
#    5336 ind, dep1, dep2 = map(
# -> 5337     ma.masked_invalid, self._process_unit_info(
#    5338         [(ind_dir, ind), (dep_dir, dep1), (dep_dir, dep2)], kwargs))
#    5340 for name, array in [
#    5341         (ind_dir, ind), (f"{dep_dir}1", dep1), (f"{dep_dir}2", dep2)]:
#    5342     if array.ndim > 1:
#
# File ~/opt/anaconda3/envs/covid-env/lib/python3.9/site-packages/matplotlib/axes/_base.py:2567, in _AxesBase._process_unit_info(self, datasets, kwargs, convert)
#    2565             if dataset_axis_name == axis_name and data is not None:
#    2566                 axis.update_units(data)
# -> 2567 return [axis_map[axis_name].convert_units(data)
#    2568         if convert and data is not None else data
#    2569         for axis_name, data in datasets]
#
# File ~/opt/anaconda3/envs/covid-env/lib/python3.9/site-packages/matplotlib/axes/_base.py:2567, in <listcomp>(.0)
#    2565             if dataset_axis_name == axis_name and data is not None:
#    2566                 axis.update_units(data)
# -> 2567 return [axis_map[axis_name].convert_units(data)
#    2568         if convert and data is not None else data
#    2569         for axis_name, data in datasets]
#
# File ~/opt/anaconda3/envs/covid-env/lib/python3.9/site-packages/matplotlib/axis.py:1734, in Axis.convert_units(self, x)
#    1732     ret = self.converter.convert(x, self.units, self)
#    1733 except Exception as e:
# -> 1734     raise munits.ConversionError('Failed to convert value(s) to axis '
#    1735                                  f'units: {x!r}') from e
#    1736 return ret
#
# ConversionError: Failed to convert value(s) to axis units: Index(['intercept.Target', 'intercept.PC1', 'intercept.PC2',
#        'L1.Target.Target', 'L1.PC1.Target', 'L1.PC2.Target',
#        'L2.Target.Target', 'L2.PC1.Target', 'L2.PC2.Target',
#        'L3.Target.Target', 'L3.PC1.Target', 'L3.PC2.Target',
#        'L4.Target.Target', 'L4.PC1.Target', 'L4.PC2.Target',
#        'L5.Target.Target', 'L5.PC1.Target', 'L5.PC2.Target',
#        'L6.Target.Target', 'L6.PC1.Target', 'L6.PC2.Target',
#        'L7.Target.Target', 'L7.PC1.Target', 'L7.PC2.Target',
#        'L8.Target.Target', 'L8.PC1.Target', 'L8.PC2.Target', 'L1.Target.PC1',
#        'L1.PC1.PC1', 'L1.PC2.PC1', 'L2.Target.PC1', 'L2.PC1.PC1', 'L2.PC2.PC1',
#        'L3.Target.PC1', 'L3.PC1.PC1', 'L3.PC2.PC1', 'L4.Target.PC1',
#        'L4.PC1.PC1', 'L4.PC2.PC1', 'L5.Target.PC1', 'L5.PC1.PC1', 'L5.PC2.PC1',
#        'L6.Target.PC1', 'L6.PC1.PC1', 'L6.PC2.PC1', 'L7.Target.PC1',
#        'L7.PC1.PC1', 'L7.PC2.PC1', 'L8.Target.PC1', 'L8.PC1.PC1', 'L8.PC2.PC1',
#        'L1.Target.PC2', 'L1.PC1.PC2', 'L1.PC2.PC2', 'L2.Target.PC2',
#        'L2.PC1.PC2', 'L2.PC2.PC2', 'L3.Target.PC2', 'L3.PC1.PC2', 'L3.PC2.PC2',
#        'L4.Target.PC2', 'L4.PC1.PC2', 'L4.PC2.PC2', 'L5.Target.PC2',
#        'L5.PC1.PC2', 'L5.PC2.PC2', 'L6.Target.PC2', 'L6.PC1.PC2', 'L6.PC2.PC2',
#        'L7.Target.PC2', 'L7.PC1.PC2', 'L7.PC2.PC2', 'L8.Target.PC2',
#        'L8.PC1.PC2', 'L8.PC2.PC2', 'sqrt.var.Target', 'sqrt.cov.Target.PC1',
#        'sqrt.var.PC1', 'sqrt.cov.Target.PC2', 'sqrt.cov.PC1.PC2',
#        'sqrt.var.PC2'],
#       dtype='object')

# %%
#plotting the VAR model predictions vs. the test data
test_vs_pred=pd.concat([var_df["Target"],predictions["Target predicted"]],axis=1)
ax = test_vs_pred.plot(figsize=(12,5))
ax.plot(y_test, label='Testing Data')
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5));

# %%
# Looking at the loss functions to evaluate how our data preformed
print('MAE:', np.mean(abs(predictions["Target predicted"] - y_test.values)))
print('RMSE:', np.sqrt(np.mean((predictions["Target predicted"] - y_test.values)**2)))
print('MAPE:', np.mean(abs((predictions["Target predicted"] - y_test.values)/y_test.values)))

# %% [markdown]
# ### Validation Data VAR Model

# %% [markdown]
# # Final Model Evaluation

# %% [markdown]
# # Conclusion
